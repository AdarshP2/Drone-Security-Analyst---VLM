# %%
import cv2
import sqlite3
import math
import numpy as np
from datetime import timedelta

# YOLOv8 from Ultralytics
from ultralytics import YOLO

# BLIP for object captioning
from transformers import BlipProcessor, BlipForConditionalGeneration
from PIL import Image

# %%
DB_NAME = "drone_security.db"

# 1) DATABASE INITIALIZATION
def init_db(db_name=DB_NAME):
    conn = sqlite3.connect(db_name)
    c = conn.cursor()
    
    # Table for storing each detection
    c.execute('''
        CREATE TABLE IF NOT EXISTS detections (
            detection_id INTEGER PRIMARY KEY AUTOINCREMENT,
            timestamp TEXT,
            yolo_label TEXT,
            color TEXT,
            confidence REAL,
            blip_caption TEXT
        )
    ''')
    
    # Table for alerts
    c.execute('''
        CREATE TABLE IF NOT EXISTS alerts (
            alert_id INTEGER PRIMARY KEY AUTOINCREMENT,
            timestamp TEXT,
            alert_message TEXT
        )
    ''')

    # NEW: Table for telemetry
    c.execute('''
        CREATE TABLE IF NOT EXISTS telemetry (
            telemetry_id INTEGER PRIMARY KEY AUTOINCREMENT,
            timestamp TEXT,
            latitude REAL,
            longitude REAL,
            altitude REAL
        )
    ''')
    
    conn.commit()
    conn.close()

init_db()
print("Database initialized.")
# Out:
# Database initialized.

# %%
yolo_model = YOLO("yolov8n.pt")  
print("YOLOv8 model loaded.")

# BLIP
blip_processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
blip_model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")
print("BLIP model loaded.")
# Out:
# YOLOv8 model loaded.
# BLIP model loaded.

# %%
def approximate_color_name(r, g, b):
    """
    Simple mapping of (r, g, b) to a named color. 
    Naive approach, can be improved if needed.
    """
    color_map = {
        "red": (255, 0, 0),
        "green": (0, 255, 0),
        "blue": (0, 0, 255),
        "yellow": (255, 255, 0),
        "white": (255, 255, 255),
        "black": (0, 0, 0),
        "gray": (128, 128, 128),
        "silver": (192, 192, 192)
    }
    
    min_dist = float("inf")
    chosen_color = "unknown"
    for cname, (cr, cg, cb) in color_map.items():
        dist = math.sqrt((r - cr)**2 + (g - cg)**2 + (b - cb)**2)
        if dist < min_dist:
            min_dist = dist
            chosen_color = cname
    return chosen_color

def get_box_color(frame, box):
    """
    Crop bounding box from frame and compute approximate color name.
    """
    x1, y1, x2, y2 = map(int, box)
    h, w, _ = frame.shape
    x1, y1 = max(0, x1), max(0, y1)
    x2, y2 = min(w-1, x2), min(h-1, y2)
    
    if x2 <= x1 or y2 <= y1:
        return "unknown"
    
    crop = frame[y1:y2, x1:x2]
    mean_bgr = crop.reshape(-1, 3).mean(axis=0)
    b, g, r = mean_bgr
    return approximate_color_name(r, g, b)

def caption_object_with_blip(frame, box):
    """
    Crop bounding box from frame, pass it to BLIP for a short caption.
    """
    x1, y1, x2, y2 = map(int, box)
    h, w, _ = frame.shape
    x1, y1 = max(0, x1), max(0, y1)
    x2, y2 = min(w-1, x2), min(h-1, y2)
    
    if x2 <= x1 or y2 <= y1:
        return "N/A"
    
    crop = frame[y1:y2, x1:x2]
    pil_image = Image.fromarray(cv2.cvtColor(crop, cv2.COLOR_BGR2RGB))
    
    inputs = blip_processor(images=pil_image, return_tensors="pt")
    output_ids = blip_model.generate(**inputs, max_new_tokens=30)
    caption = blip_processor.decode(output_ids[0], skip_special_tokens=True)
    return caption

def simulate_telemetry_data(frame_seconds):
    """
    Simulate drone telemetry (latitude, longitude, altitude) for demonstration.
    Replace with real or more advanced simulation logic as needed.
    """
    # For a simple example, let's increment lat/lon/alt slightly each second
    base_lat = 37.7749
    base_lon = -122.4194
    base_alt = 100.0
    
    # e.g., add small increments per second
    lat = base_lat + (frame_seconds * 0.0001)
    lon = base_lon + (frame_seconds * 0.0001)
    alt = base_alt + (frame_seconds * 0.01)
    
    return lat, lon, alt

# 4) VIDEO ANALYSIS & LOGGING
def analyze_video(video_path, db_name=DB_NAME, skip_frames=30):
    """
    - Reads video frame by frame.
    - Simulates telemetry for each frame, stores in 'telemetry' table.
    - Runs YOLOv8 detection on every nth frame (skip_frames).
    - For each bounding box that is a relevant object (car, truck, bus, etc.), 
      we crop it and use BLIP to get a more detailed caption.
    - We also approximate the color from the bounding box.
    - Logs the detection (yolo_label, color, confidence, BLIP caption) with a timestamp in the DB.
    - Generates an alert if a silver car is detected.
    """
    conn = sqlite3.connect(db_name)
    c = conn.cursor()
    
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return
    
    fps = cap.get(cv2.CAP_PROP_FPS)
    frame_index = 0
    
    # List of YOLO classes we want to analyze in detail
    relevant_labels = {"car", "truck", "bus", "motorcycle"}
    
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        
        # Compute the time in seconds for the current frame
        frame_time_seconds = int(frame_index / fps)
        video_timestamp = str(timedelta(seconds=frame_time_seconds))
        
        # -- TELEMETRY SIMULATION & STORAGE --
        lat, lon, alt = simulate_telemetry_data(frame_time_seconds)
        c.execute('''
            INSERT INTO telemetry (timestamp, latitude, longitude, altitude)
            VALUES (?, ?, ?, ?)
        ''', (video_timestamp, lat, lon, alt))
        
        # -- ONLY DETECT EVERY 'skip_frames' FRAMES --
        if frame_index % skip_frames == 0:
            results = yolo_model.predict(frame, conf=0.3)
            if len(results) > 0:
                for box in results[0].boxes:
                    cls_id = int(box.cls[0])
                    label = results[0].names[cls_id]  # e.g. "car", "truck"
                    conf = float(box.conf[0])
                    xyxy = box.xyxy[0]
                    
                    if label in relevant_labels:
                        # 1) Approx color
                        color_name = get_box_color(frame, xyxy)
                        # 2) BLIP caption
                        obj_caption = caption_object_with_blip(frame, xyxy)
                        
                        # Insert detection into DB
                        c.execute('''
                            INSERT INTO detections (timestamp, yolo_label, color, confidence, blip_caption)
                            VALUES (?, ?, ?, ?, ?)
                        ''', (video_timestamp, label, color_name, conf, obj_caption))
                        
                        # Print logs
                        print(f"Logs: {color_name} {label} (conf={conf:.2f}) "
                              f"| BLIP: {obj_caption} | Time: {video_timestamp} "
                              f"| Telemetry: lat={lat:.5f}, lon={lon:.5f}, alt={alt:.2f}")
                        
                        # -- ALERT GENERATION: SILVER CAR --
                        if label == "car" and color_name == "silver":
                            alert_message = (f"ALERT: Silver car detected at {video_timestamp} "
                                             f"(lat={lat:.5f}, lon={lon:.5f}, alt={alt:.2f})")
                            c.execute('''
                                INSERT INTO alerts (timestamp, alert_message)
                                VALUES (?, ?)
                            ''', (video_timestamp, alert_message))
                            print(alert_message)
        
        frame_index += 1
    
    conn.commit()
    conn.close()
    cap.release()
    print("Video analysis complete.")

# 5) RUN THE ANALYSIS

# %%
VIDEO_PATH = "/Users/adarshpandey/Desktop/Project FlytBase/data/Test Video.mp4"  # Replace with your own video path
analyze_video(VIDEO_PATH, skip_frames=30)
# Out:
# 0: 384x640 3 cars, 80.7ms
# Speed: 12.1ms preprocess, 80.7ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.72) | BLIP: a car driving down a road with a sign on it | Time: 0:00:00 | Telemetry: lat=37.77490, lon=-122.41940, alt=100.00
# Logs: black car (conf=0.54) | BLIP: a blue car driving down a road | Time: 0:00:00 | Telemetry: lat=37.77490, lon=-122.41940, alt=100.00
# Logs: gray car (conf=0.40) | BLIP: a truck driving down a highway with a red light | Time: 0:00:00 | Telemetry: lat=37.77490, lon=-122.41940, alt=100.00
#
# 0: 384x640 3 cars, 264.1ms
# Speed: 10.9ms preprocess, 264.1ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
# Logs: black car (conf=0.82) | BLIP: a car driving down a road with a sign on the side | Time: 0:00:00 | Telemetry: lat=37.77490, lon=-122.41940, alt=100.00
# Logs: gray car (conf=0.43) | BLIP: a bus is driving down the road | Time: 0:00:00 | Telemetry: lat=37.77490, lon=-122.41940, alt=100.00
# Logs: silver car (conf=0.31) | BLIP: a white van parked in a parking lot | Time: 0:00:00 | Telemetry: lat=37.77490, lon=-122.41940, alt=100.00
# ALERT: Silver car detected at 0:00:00 (lat=37.77490, lon=-122.41940, alt=100.00)
#
# 0: 384x640 2 cars, 1 bus, 180.9ms
# Speed: 3.3ms preprocess, 180.9ms inference, 11.3ms postprocess per image at shape (1, 3, 384, 640)
# Logs: black car (conf=0.61) | BLIP: a car driving down a road with a person in the back | Time: 0:00:01 | Telemetry: lat=37.77500, lon=-122.41930, alt=100.01
# Logs: gray car (conf=0.35) | BLIP: a white van is parked in the dark | Time: 0:00:01 | Telemetry: lat=37.77500, lon=-122.41930, alt=100.01
# Logs: gray bus (conf=0.31) | BLIP: a truck driving down a road with a bus behind it | Time: 0:00:01 | Telemetry: lat=37.77500, lon=-122.41930, alt=100.01
#
# 0: 384x640 2 cars, 1 truck, 173.1ms
# Speed: 33.9ms preprocess, 173.1ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.41) | BLIP: a white van is parked in the dark | Time: 0:00:02 | Telemetry: lat=37.77510, lon=-122.41920, alt=100.02
# Logs: gray car (conf=0.39) | BLIP: a truck with a yellow cab and a black cab | Time: 0:00:02 | Telemetry: lat=37.77510, lon=-122.41920, alt=100.02
# Logs: gray truck (conf=0.32) | BLIP: a white van driving down a street | Time: 0:00:02 | Telemetry: lat=37.77510, lon=-122.41920, alt=100.02
#
# 0: 384x640 3 cars, 102.4ms
# Speed: 3.8ms preprocess, 102.4ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.65) | BLIP: the bmw x6 is seen in this aerial image | Time: 0:00:03 | Telemetry: lat=37.77520, lon=-122.41910, alt=100.03
# Logs: gray car (conf=0.55) | BLIP: a white car driving down a street | Time: 0:00:03 | Telemetry: lat=37.77520, lon=-122.41910, alt=100.03
# Logs: gray car (conf=0.37) | BLIP: a yellow van driving down a street next to a building | Time: 0:00:03 | Telemetry: lat=37.77520, lon=-122.41910, alt=100.03
#
# 0: 384x640 3 cars, 1 truck, 97.9ms
# Speed: 3.8ms preprocess, 97.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.63) | BLIP: a car driving down a road with a police car behind it | Time: 0:00:04 | Telemetry: lat=37.77530, lon=-122.41900, alt=100.04
# Logs: gray car (conf=0.41) | BLIP: a car is seen in this image from the video | Time: 0:00:04 | Telemetry: lat=37.77530, lon=-122.41900, alt=100.04
# Logs: gray car (conf=0.39) | BLIP: a school bus driving down a street | Time: 0:00:04 | Telemetry: lat=37.77530, lon=-122.41900, alt=100.04
# Logs: gray truck (conf=0.30) | BLIP: a school bus driving down the street | Time: 0:00:04 | Telemetry: lat=37.77530, lon=-122.41900, alt=100.04
#
# 0: 384x640 5 cars, 1 bus, 96.4ms
# Speed: 2.6ms preprocess, 96.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.64) | BLIP: a white car driving down a street | Time: 0:00:05 | Telemetry: lat=37.77540, lon=-122.41890, alt=100.05
# Logs: gray car (conf=0.62) | BLIP: a car driving down a road with a light on it | Time: 0:00:05 | Telemetry: lat=37.77540, lon=-122.41890, alt=100.05
# Logs: black car (conf=0.62) | BLIP: a car is seen in this image | Time: 0:00:05 | Telemetry: lat=37.77540, lon=-122.41890, alt=100.05
# Logs: gray car (conf=0.48) | BLIP: a white van driving down a road | Time: 0:00:05 | Telemetry: lat=37.77540, lon=-122.41890, alt=100.05
# Logs: gray car (conf=0.43) | BLIP: a school bus with a yellow top | Time: 0:00:05 | Telemetry: lat=37.77540, lon=-122.41890, alt=100.05
# Logs: gray bus (conf=0.36) | BLIP: a school bus with a sign on the back | Time: 0:00:05 | Telemetry: lat=37.77540, lon=-122.41890, alt=100.05
#
# 0: 384x640 5 cars, 83.3ms
# Speed: 3.5ms preprocess, 83.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.85) | BLIP: a car driving down a street in the city | Time: 0:00:06 | Telemetry: lat=37.77550, lon=-122.41880, alt=100.06
# Logs: gray car (conf=0.75) | BLIP: a white van with red roof and a red roof | Time: 0:00:06 | Telemetry: lat=37.77550, lon=-122.41880, alt=100.06
# Logs: gray car (conf=0.65) | BLIP: a red van driving down a road with smoke in the background | Time: 0:00:06 | Telemetry: lat=37.77550, lon=-122.41880, alt=100.06
# Logs: gray car (conf=0.64) | BLIP: a white car driving down a road | Time: 0:00:06 | Telemetry: lat=37.77550, lon=-122.41880, alt=100.06
# Logs: black car (conf=0.54) | BLIP: a car is seen in this image | Time: 0:00:06 | Telemetry: lat=37.77550, lon=-122.41880, alt=100.06
#
# 0: 384x640 6 cars, 121.7ms
# Speed: 11.7ms preprocess, 121.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.66) | BLIP: the car is seen in this image | Time: 0:00:07 | Telemetry: lat=37.77560, lon=-122.41870, alt=100.07
# Logs: gray car (conf=0.65) | BLIP: a red and white car parked in a parking lot | Time: 0:00:07 | Telemetry: lat=37.77560, lon=-122.41870, alt=100.07
# Logs: black car (conf=0.61) | BLIP: a car driving down the road at night | Time: 0:00:07 | Telemetry: lat=37.77560, lon=-122.41870, alt=100.07
# Logs: gray car (conf=0.60) | BLIP: a car is parked in the parking lot | Time: 0:00:07 | Telemetry: lat=37.77560, lon=-122.41870, alt=100.07
# Logs: gray car (conf=0.45) | BLIP: a car driving down a road with a sign on the back | Time: 0:00:07 | Telemetry: lat=37.77560, lon=-122.41870, alt=100.07
# Logs: gray car (conf=0.44) | BLIP: a red van driving down a road | Time: 0:00:07 | Telemetry: lat=37.77560, lon=-122.41870, alt=100.07
#
# 0: 384x640 6 cars, 106.3ms
# Speed: 3.5ms preprocess, 106.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.70) | BLIP: a white car driving down a road | Time: 0:00:08 | Telemetry: lat=37.77570, lon=-122.41860, alt=100.08
# Logs: gray car (conf=0.69) | BLIP: a car is seen in this image | Time: 0:00:08 | Telemetry: lat=37.77570, lon=-122.41860, alt=100.08
# Logs: gray car (conf=0.62) | BLIP: a red van is driving down the street | Time: 0:00:08 | Telemetry: lat=37.77570, lon=-122.41860, alt=100.08
# Logs: gray car (conf=0.49) | BLIP: a car with a white light on it ' s hood | Time: 0:00:08 | Telemetry: lat=37.77570, lon=-122.41860, alt=100.08
# Logs: gray car (conf=0.46) | BLIP: a car driving down the road | Time: 0:00:08 | Telemetry: lat=37.77570, lon=-122.41860, alt=100.08
# Logs: gray car (conf=0.40) | BLIP: a car driving down a road with fog | Time: 0:00:08 | Telemetry: lat=37.77570, lon=-122.41860, alt=100.08
#
# 0: 384x640 8 cars, 83.1ms
# Speed: 3.3ms preprocess, 83.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Logs: black car (conf=0.78) | BLIP: a car driving down a street with a white line | Time: 0:00:09 | Telemetry: lat=37.77580, lon=-122.41850, alt=100.09
# Logs: gray car (conf=0.72) | BLIP: a car driving down a road with a white car | Time: 0:00:09 | Telemetry: lat=37.77580, lon=-122.41850, alt=100.09
# Logs: black car (conf=0.70) | BLIP: a car driving down a road with a sign | Time: 0:00:09 | Telemetry: lat=37.77580, lon=-122.41850, alt=100.09
# Logs: gray car (conf=0.66) | BLIP: a car is parked in a parking lot | Time: 0:00:09 | Telemetry: lat=37.77580, lon=-122.41850, alt=100.09
# Logs: gray car (conf=0.62) | BLIP: a car with a black hood and a white hood | Time: 0:00:09 | Telemetry: lat=37.77580, lon=-122.41850, alt=100.09
# Logs: gray car (conf=0.59) | BLIP: a car driving down a street at night | Time: 0:00:09 | Telemetry: lat=37.77580, lon=-122.41850, alt=100.09
# Logs: gray car (conf=0.47) | BLIP: a car is seen through a window in this und photo | Time: 0:00:09 | Telemetry: lat=37.77580, lon=-122.41850, alt=100.09
# Logs: gray car (conf=0.38) | BLIP: a car is shown in this image | Time: 0:00:09 | Telemetry: lat=37.77580, lon=-122.41850, alt=100.09
#
# 0: 384x640 7 cars, 97.2ms
# Speed: 6.4ms preprocess, 97.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Logs: black car (conf=0.77) | BLIP: a car driving down a road with a white sign | Time: 0:00:10 | Telemetry: lat=37.77590, lon=-122.41840, alt=100.10
# Logs: gray car (conf=0.71) | BLIP: a white car driving down a road | Time: 0:00:10 | Telemetry: lat=37.77590, lon=-122.41840, alt=100.10
# Logs: black car (conf=0.63) | BLIP: the police car is seen in this image | Time: 0:00:10 | Telemetry: lat=37.77590, lon=-122.41840, alt=100.10
# Logs: gray car (conf=0.57) | BLIP: a car is parked in a parking lot | Time: 0:00:10 | Telemetry: lat=37.77590, lon=-122.41840, alt=100.10
# Logs: gray car (conf=0.44) | BLIP: a car driving down a road at night | Time: 0:00:10 | Telemetry: lat=37.77590, lon=-122.41840, alt=100.10
# Logs: gray car (conf=0.39) | BLIP: a police car is seen in this und photo | Time: 0:00:10 | Telemetry: lat=37.77590, lon=-122.41840, alt=100.10
# Logs: gray car (conf=0.32) | BLIP: a white bus is driving down the road | Time: 0:00:10 | Telemetry: lat=37.77590, lon=-122.41840, alt=100.10
#
# 0: 384x640 7 cars, 99.3ms
# Speed: 2.9ms preprocess, 99.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Logs: black car (conf=0.81) | BLIP: a car driving down a road with a sign on it | Time: 0:00:11 | Telemetry: lat=37.77600, lon=-122.41830, alt=100.11
# Logs: gray car (conf=0.76) | BLIP: a white car driving down a highway | Time: 0:00:11 | Telemetry: lat=37.77600, lon=-122.41830, alt=100.11
# Logs: black car (conf=0.67) | BLIP: a car driving down a street with a light on it | Time: 0:00:11 | Telemetry: lat=37.77600, lon=-122.41830, alt=100.11
# Logs: gray car (conf=0.55) | BLIP: a car driving down a road at night | Time: 0:00:11 | Telemetry: lat=37.77600, lon=-122.41830, alt=100.11
# Logs: gray car (conf=0.54) | BLIP: a car driving down a street with a blue light | Time: 0:00:11 | Telemetry: lat=37.77600, lon=-122.41830, alt=100.11
# Logs: gray car (conf=0.45) | BLIP: the car is seen in this image | Time: 0:00:11 | Telemetry: lat=37.77600, lon=-122.41830, alt=100.11
# Logs: gray car (conf=0.39) | BLIP: a white van is driving down the street | Time: 0:00:11 | Telemetry: lat=37.77600, lon=-122.41830, alt=100.11
#
# 0: 384x640 8 cars, 111.9ms
# Speed: 2.9ms preprocess, 111.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.81) | BLIP: a white car driving down a road | Time: 0:00:12 | Telemetry: lat=37.77610, lon=-122.41820, alt=100.12
# Logs: black car (conf=0.80) | BLIP: a car driving down a road with a blue car | Time: 0:00:12 | Telemetry: lat=37.77610, lon=-122.41820, alt=100.12
# Logs: gray car (conf=0.64) | BLIP: a car driving down a highway | Time: 0:00:12 | Telemetry: lat=37.77610, lon=-122.41820, alt=100.12
# Logs: gray car (conf=0.60) | BLIP: a car driving down a road with a person in the back | Time: 0:00:12 | Telemetry: lat=37.77610, lon=-122.41820, alt=100.12
# Logs: gray car (conf=0.54) | BLIP: a car is seen from above as it drives down a road | Time: 0:00:12 | Telemetry: lat=37.77610, lon=-122.41820, alt=100.12
# Logs: black car (conf=0.53) | BLIP: a car driving down a road with fog | Time: 0:00:12 | Telemetry: lat=37.77610, lon=-122.41820, alt=100.12
# Logs: gray car (conf=0.52) | BLIP: a car is seen in this image | Time: 0:00:12 | Telemetry: lat=37.77610, lon=-122.41820, alt=100.12
# Logs: gray car (conf=0.50) | BLIP: a white van driving down a street | Time: 0:00:12 | Telemetry: lat=37.77610, lon=-122.41820, alt=100.12
#
# 0: 384x640 6 cars, 1 bus, 87.2ms
# Speed: 7.9ms preprocess, 87.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.71) | BLIP: a car is parked in a parking lot | Time: 0:00:13 | Telemetry: lat=37.77620, lon=-122.41810, alt=100.13
# Logs: gray car (conf=0.65) | BLIP: a car parked in a parking lot | Time: 0:00:13 | Telemetry: lat=37.77620, lon=-122.41810, alt=100.13
# Logs: gray car (conf=0.62) | BLIP: a car is seen in this image | Time: 0:00:13 | Telemetry: lat=37.77620, lon=-122.41810, alt=100.13
# Logs: gray car (conf=0.61) | BLIP: a car driving down a road with a person in the passenger seat | Time: 0:00:13 | Telemetry: lat=37.77620, lon=-122.41810, alt=100.13
# Logs: gray bus (conf=0.56) | BLIP: a semi semi semi semi semi semi semi semi semi semi semi semi semi semi semi semi semi semi semi semi semi semi semi semi semi semi semi | Time: 0:00:13 | Telemetry: lat=37.77620, lon=-122.41810, alt=100.13
# Logs: black car (conf=0.54) | BLIP: the new chevrolet camaro is a new car that will be available in the us | Time: 0:00:13 | Telemetry: lat=37.77620, lon=-122.41810, alt=100.13
# Logs: gray car (conf=0.46) | BLIP: a white van is driving down the road | Time: 0:00:13 | Telemetry: lat=37.77620, lon=-122.41810, alt=100.13
#
# 0: 384x640 3 cars, 92.0ms
# Speed: 8.2ms preprocess, 92.0ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.78) | BLIP: a car is seen in this und photo | Time: 0:00:14 | Telemetry: lat=37.77630, lon=-122.41800, alt=100.14
# Logs: gray car (conf=0.53) | BLIP: a white car parked in a parking lot | Time: 0:00:14 | Telemetry: lat=37.77630, lon=-122.41800, alt=100.14
# Logs: gray car (conf=0.34) | BLIP: a white van driving down a road | Time: 0:00:14 | Telemetry: lat=37.77630, lon=-122.41800, alt=100.14
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 197.3ms
# Speed: 4.6ms preprocess, 197.3ms inference, 18.5ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.74) | BLIP: a car is driving down the street in the dark | Time: 0:00:15 | Telemetry: lat=37.77640, lon=-122.41790, alt=100.15
# Logs: gray car (conf=0.56) | BLIP: a car with a white hood and hood on | Time: 0:00:15 | Telemetry: lat=37.77640, lon=-122.41790, alt=100.15
# Logs: gray bus (conf=0.43) | BLIP: a truck with a large trailer on the back | Time: 0:00:15 | Telemetry: lat=37.77640, lon=-122.41790, alt=100.15
# Logs: gray car (conf=0.41) | BLIP: a white car driving down a street | Time: 0:00:15 | Telemetry: lat=37.77640, lon=-122.41790, alt=100.15
# Logs: gray truck (conf=0.40) | BLIP: a large white truck parked in a parking lot | Time: 0:00:15 | Telemetry: lat=37.77640, lon=-122.41790, alt=100.15
#
# 0: 384x640 4 cars, 1 bus, 1 train, 1 truck, 101.4ms
# Speed: 9.3ms preprocess, 101.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.75) | BLIP: a car is driving down the street in a parking lot | Time: 0:00:16 | Telemetry: lat=37.77650, lon=-122.41780, alt=100.16
# Logs: gray car (conf=0.64) | BLIP: a white van driving down a road next to a building | Time: 0:00:16 | Telemetry: lat=37.77650, lon=-122.41780, alt=100.16
# Logs: gray car (conf=0.62) | BLIP: a white car driving down a street | Time: 0:00:16 | Telemetry: lat=37.77650, lon=-122.41780, alt=100.16
# Logs: gray bus (conf=0.49) | BLIP: a truck with a trailer on the back | Time: 0:00:16 | Telemetry: lat=37.77650, lon=-122.41780, alt=100.16
# Logs: gray car (conf=0.42) | BLIP: a car is shown in this image | Time: 0:00:16 | Telemetry: lat=37.77650, lon=-122.41780, alt=100.16
# Logs: gray truck (conf=0.33) | BLIP: a white truck with a black trailer in the back | Time: 0:00:16 | Telemetry: lat=37.77650, lon=-122.41780, alt=100.16
#
# 0: 384x640 5 cars, 1 train, 1 truck, 111.1ms
# Speed: 6.6ms preprocess, 111.1ms inference, 15.2ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.73) | BLIP: a white car driving down a street | Time: 0:00:17 | Telemetry: lat=37.77660, lon=-122.41770, alt=100.17
# Logs: gray car (conf=0.58) | BLIP: a car is seen in this image | Time: 0:00:17 | Telemetry: lat=37.77660, lon=-122.41770, alt=100.17
# Logs: gray car (conf=0.42) | BLIP: a white van driving down a road next to a building | Time: 0:00:17 | Telemetry: lat=37.77660, lon=-122.41770, alt=100.17
# Logs: gray car (conf=0.32) | BLIP: a car is seen in this image | Time: 0:00:17 | Telemetry: lat=37.77660, lon=-122.41770, alt=100.17
# Logs: gray truck (conf=0.32) | BLIP: a white van driving down a road next to a building | Time: 0:00:17 | Telemetry: lat=37.77660, lon=-122.41770, alt=100.17
# Logs: gray car (conf=0.32) | BLIP: a blurry image of a cloud | Time: 0:00:17 | Telemetry: lat=37.77660, lon=-122.41770, alt=100.17
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 103.7ms
# Speed: 4.2ms preprocess, 103.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.77) | BLIP: a white car driving down a street | Time: 0:00:18 | Telemetry: lat=37.77670, lon=-122.41760, alt=100.18
# Logs: gray car (conf=0.70) | BLIP: a car is seen in this image from the video | Time: 0:00:18 | Telemetry: lat=37.77670, lon=-122.41760, alt=100.18
# Logs: gray bus (conf=0.67) | BLIP: a white truck with a black trailer in the back | Time: 0:00:18 | Telemetry: lat=37.77670, lon=-122.41760, alt=100.18
# Logs: gray car (conf=0.54) | BLIP: a white van driving down a road | Time: 0:00:18 | Telemetry: lat=37.77670, lon=-122.41760, alt=100.18
# Logs: gray truck (conf=0.41) | BLIP: a white van driving down a street | Time: 0:00:18 | Telemetry: lat=37.77670, lon=-122.41760, alt=100.18
# Logs: gray car (conf=0.38) | BLIP: a car is parked in the dark | Time: 0:00:18 | Telemetry: lat=37.77670, lon=-122.41760, alt=100.18
# Logs: gray truck (conf=0.34) | BLIP: a white truck with a black trailer in the back | Time: 0:00:18 | Telemetry: lat=37.77670, lon=-122.41760, alt=100.18
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 93.7ms
# Speed: 3.5ms preprocess, 93.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.72) | BLIP: a car is seen in this image | Time: 0:00:19 | Telemetry: lat=37.77680, lon=-122.41750, alt=100.19
# Logs: gray car (conf=0.71) | BLIP: a white car driving down a street | Time: 0:00:19 | Telemetry: lat=37.77680, lon=-122.41750, alt=100.19
# Logs: gray bus (conf=0.56) | BLIP: a white van driving down a road | Time: 0:00:19 | Telemetry: lat=37.77680, lon=-122.41750, alt=100.19
# Logs: gray truck (conf=0.31) | BLIP: a white box with a black lid | Time: 0:00:19 | Telemetry: lat=37.77680, lon=-122.41750, alt=100.19
#
# 0: 384x640 2 cars, 1 truck, 154.6ms
# Speed: 2.3ms preprocess, 154.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.84) | BLIP: a white car driving down a road | Time: 0:00:20 | Telemetry: lat=37.77690, lon=-122.41740, alt=100.20
# Logs: gray car (conf=0.70) | BLIP: a car is seen in this image | Time: 0:00:20 | Telemetry: lat=37.77690, lon=-122.41740, alt=100.20
# Logs: gray truck (conf=0.30) | BLIP: a black and white photo of a square | Time: 0:00:20 | Telemetry: lat=37.77690, lon=-122.41740, alt=100.20
#
# 0: 384x640 3 cars, 153.5ms
# Speed: 4.1ms preprocess, 153.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.76) | BLIP: a car is driving down the road with a police car behind it | Time: 0:00:21 | Telemetry: lat=37.77700, lon=-122.41730, alt=100.21
# Logs: gray car (conf=0.38) | BLIP: a blurry image of a car in the dark | Time: 0:00:21 | Telemetry: lat=37.77700, lon=-122.41730, alt=100.21
# Logs: gray car (conf=0.37) | BLIP: a black and white photo of a man in a suit | Time: 0:00:21 | Telemetry: lat=37.77700, lon=-122.41730, alt=100.21
#
# 0: 384x640 3 cars, 93.0ms
# Speed: 2.6ms preprocess, 93.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.72) | BLIP: a white truck driving down a road | Time: 0:00:22 | Telemetry: lat=37.77710, lon=-122.41720, alt=100.22
# Logs: gray car (conf=0.42) | BLIP: a blurry image of a car | Time: 0:00:22 | Telemetry: lat=37.77710, lon=-122.41720, alt=100.22
# Logs: gray car (conf=0.35) | BLIP: a blurry image of a cloud in the sky | Time: 0:00:22 | Telemetry: lat=37.77710, lon=-122.41720, alt=100.22
#
# 0: 384x640 2 cars, 104.2ms
# Speed: 4.2ms preprocess, 104.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.39) | BLIP: the police car is seen in this und photo | Time: 0:00:23 | Telemetry: lat=37.77720, lon=-122.41710, alt=100.23
# Logs: gray car (conf=0.33) | BLIP: a blurry image of a car in the dark | Time: 0:00:23 | Telemetry: lat=37.77720, lon=-122.41710, alt=100.23
#
# 0: 384x640 1 car, 104.0ms
# Speed: 2.5ms preprocess, 104.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.53) | BLIP: a blurry image of a person in a car | Time: 0:00:24 | Telemetry: lat=37.77730, lon=-122.41700, alt=100.24
#
# 0: 384x640 2 cars, 1 truck, 88.6ms
# Speed: 3.9ms preprocess, 88.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.57) | BLIP: the gmc is seen in this und photo | Time: 0:00:25 | Telemetry: lat=37.77740, lon=-122.41690, alt=100.25
# Logs: gray car (conf=0.50) | BLIP: a blurry image of a car in the dark | Time: 0:00:25 | Telemetry: lat=37.77740, lon=-122.41690, alt=100.25
# Logs: gray truck (conf=0.34) | BLIP: the gmc is seen in this und photo | Time: 0:00:25 | Telemetry: lat=37.77740, lon=-122.41690, alt=100.25
#
# 0: 384x640 3 cars, 1 truck, 131.0ms
# Speed: 5.1ms preprocess, 131.0ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.42) | BLIP: a truck is driving down the road in the snow | Time: 0:00:26 | Telemetry: lat=37.77750, lon=-122.41680, alt=100.26
# Logs: gray car (conf=0.41) | BLIP: a blurry image of a car in the dark | Time: 0:00:26 | Telemetry: lat=37.77750, lon=-122.41680, alt=100.26
# Logs: gray truck (conf=0.41) | BLIP: a truck is driving down the road in the snow | Time: 0:00:26 | Telemetry: lat=37.77750, lon=-122.41680, alt=100.26
# Logs: gray car (conf=0.31) | BLIP: a blurry image of a cloud | Time: 0:00:26 | Telemetry: lat=37.77750, lon=-122.41680, alt=100.26
#
# 0: 384x640 1 car, 1 truck, 127.9ms
# Speed: 11.1ms preprocess, 127.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Logs: black car (conf=0.49) | BLIP: a car driving down a road with a person in the back | Time: 0:00:27 | Telemetry: lat=37.77760, lon=-122.41670, alt=100.27
# Logs: gray truck (conf=0.46) | BLIP: a car is parked on the side of the road | Time: 0:00:27 | Telemetry: lat=37.77760, lon=-122.41670, alt=100.27
#
# 0: 384x640 2 cars, 95.0ms
# Speed: 5.4ms preprocess, 95.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.62) | BLIP: a car is driving down the road in the tunnel | Time: 0:00:28 | Telemetry: lat=37.77770, lon=-122.41660, alt=100.28
# Logs: gray car (conf=0.43) | BLIP: a car is seen in this surveillance image | Time: 0:00:28 | Telemetry: lat=37.77770, lon=-122.41660, alt=100.28
#
# 0: 384x640 2 cars, 1 truck, 89.5ms
# Speed: 2.7ms preprocess, 89.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.62) | BLIP: a car is driving down the street in a parking lot | Time: 0:00:29 | Telemetry: lat=37.77780, lon=-122.41650, alt=100.29
# Logs: gray truck (conf=0.55) | BLIP: a police car is seen in this und photo | Time: 0:00:29 | Telemetry: lat=37.77780, lon=-122.41650, alt=100.29
# Logs: gray car (conf=0.34) | BLIP: a police car is seen in this und photo | Time: 0:00:29 | Telemetry: lat=37.77780, lon=-122.41650, alt=100.29
#
# 0: 384x640 4 cars, 107.9ms
# Speed: 4.4ms preprocess, 107.9ms inference, 16.3ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.74) | BLIP: a car is seen in this image from the video | Time: 0:00:30 | Telemetry: lat=37.77790, lon=-122.41640, alt=100.30
# Logs: gray car (conf=0.69) | BLIP: a car is driving down the road with other cars | Time: 0:00:30 | Telemetry: lat=37.77790, lon=-122.41640, alt=100.30
# Logs: gray car (conf=0.49) | BLIP: the car is parked in the parking lot | Time: 0:00:30 | Telemetry: lat=37.77790, lon=-122.41640, alt=100.30
# Logs: gray car (conf=0.45) | BLIP: a car is seen in this und photo | Time: 0:00:30 | Telemetry: lat=37.77790, lon=-122.41640, alt=100.30
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 121.2ms
# Speed: 10.9ms preprocess, 121.2ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.65) | BLIP: a car is parked in a parking lot | Time: 0:00:31 | Telemetry: lat=37.77800, lon=-122.41630, alt=100.31
# Logs: gray car (conf=0.63) | BLIP: a car driving down a street with a sign on it | Time: 0:00:31 | Telemetry: lat=37.77800, lon=-122.41630, alt=100.31
# Logs: gray car (conf=0.55) | BLIP: a car is seen in this image from the back | Time: 0:00:31 | Telemetry: lat=37.77800, lon=-122.41630, alt=100.31
# Logs: gray car (conf=0.48) | BLIP: a police car is seen in this und photo | Time: 0:00:31 | Telemetry: lat=37.77800, lon=-122.41630, alt=100.31
# Logs: gray bus (conf=0.39) | BLIP: a police car is seen in this und photo | Time: 0:00:31 | Telemetry: lat=37.77800, lon=-122.41630, alt=100.31
# Logs: gray car (conf=0.38) | BLIP: a blurry image of a cloud | Time: 0:00:31 | Telemetry: lat=37.77800, lon=-122.41630, alt=100.31
# Logs: gray truck (conf=0.38) | BLIP: a police car is seen in this und photo | Time: 0:00:31 | Telemetry: lat=37.77800, lon=-122.41630, alt=100.31
# Logs: gray car (conf=0.36) | BLIP: a police car driving down the road | Time: 0:00:31 | Telemetry: lat=37.77800, lon=-122.41630, alt=100.31
#
# 0: 384x640 6 cars, 96.8ms
# Speed: 5.1ms preprocess, 96.8ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.76) | BLIP: a car driving down a street with a red car | Time: 0:00:32 | Telemetry: lat=37.77810, lon=-122.41620, alt=100.32
# Logs: gray car (conf=0.68) | BLIP: a white car is driving down the street | Time: 0:00:32 | Telemetry: lat=37.77810, lon=-122.41620, alt=100.32
# Logs: gray car (conf=0.66) | BLIP: a police car is seen on the side of a road | Time: 0:00:32 | Telemetry: lat=37.77810, lon=-122.41620, alt=100.32
# Logs: gray car (conf=0.58) | BLIP: a car is seen in this image | Time: 0:00:32 | Telemetry: lat=37.77810, lon=-122.41620, alt=100.32
# Logs: gray car (conf=0.42) | BLIP: a car is parked in a parking lot | Time: 0:00:32 | Telemetry: lat=37.77810, lon=-122.41620, alt=100.32
# Logs: gray car (conf=0.38) | BLIP: a blurry image of a cloud | Time: 0:00:32 | Telemetry: lat=37.77810, lon=-122.41620, alt=100.32
#
# 0: 384x640 6 cars, 103.1ms
# Speed: 4.8ms preprocess, 103.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.78) | BLIP: a red car driving down a street | Time: 0:00:33 | Telemetry: lat=37.77820, lon=-122.41610, alt=100.33
# Logs: gray car (conf=0.71) | BLIP: a car is seen in this image | Time: 0:00:33 | Telemetry: lat=37.77820, lon=-122.41610, alt=100.33
# Logs: gray car (conf=0.57) | BLIP: a car is shown in this image | Time: 0:00:33 | Telemetry: lat=37.77820, lon=-122.41610, alt=100.33
# Logs: gray car (conf=0.53) | BLIP: a police car is seen in this image | Time: 0:00:33 | Telemetry: lat=37.77820, lon=-122.41610, alt=100.33
# Logs: gray car (conf=0.43) | BLIP: a police car is seen on the side of a road | Time: 0:00:33 | Telemetry: lat=37.77820, lon=-122.41610, alt=100.33
# Logs: gray car (conf=0.39) | BLIP: a blurry image of a city | Time: 0:00:33 | Telemetry: lat=37.77820, lon=-122.41610, alt=100.33
#
# 0: 384x640 5 cars, 91.2ms
# Speed: 3.3ms preprocess, 91.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.84) | BLIP: a car is seen in this image from the video | Time: 0:00:34 | Telemetry: lat=37.77830, lon=-122.41600, alt=100.34
# Logs: gray car (conf=0.58) | BLIP: a car is seen in this image | Time: 0:00:34 | Telemetry: lat=37.77830, lon=-122.41600, alt=100.34
# Logs: gray car (conf=0.48) | BLIP: a white car is parked in a parking lot | Time: 0:00:34 | Telemetry: lat=37.77830, lon=-122.41600, alt=100.34
# Logs: gray car (conf=0.33) | BLIP: a blurry image of a car | Time: 0:00:34 | Telemetry: lat=37.77830, lon=-122.41600, alt=100.34
# Logs: gray car (conf=0.31) | BLIP: a police car is seen in this und photo | Time: 0:00:34 | Telemetry: lat=37.77830, lon=-122.41600, alt=100.34
#
# 0: 384x640 3 cars, 73.3ms
# Speed: 2.9ms preprocess, 73.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.80) | BLIP: a car is seen in this image | Time: 0:00:35 | Telemetry: lat=37.77840, lon=-122.41590, alt=100.35
# Logs: gray car (conf=0.52) | BLIP: a car is seen in this image | Time: 0:00:35 | Telemetry: lat=37.77840, lon=-122.41590, alt=100.35
# Logs: gray car (conf=0.40) | BLIP: a man in a black shirt and black pants | Time: 0:00:35 | Telemetry: lat=37.77840, lon=-122.41590, alt=100.35
#
# 0: 384x640 3 cars, 86.5ms
# Speed: 2.5ms preprocess, 86.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.58) | BLIP: a car is seen in this image | Time: 0:00:36 | Telemetry: lat=37.77850, lon=-122.41580, alt=100.36
# Logs: gray car (conf=0.49) | BLIP: a blur of a car driving down a road | Time: 0:00:36 | Telemetry: lat=37.77850, lon=-122.41580, alt=100.36
# Logs: gray car (conf=0.39) | BLIP: a computer screen with a black background | Time: 0:00:36 | Telemetry: lat=37.77850, lon=-122.41580, alt=100.36
#
# 0: 384x640 2 cars, 108.7ms
# Speed: 2.5ms preprocess, 108.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.49) | BLIP: a car is seen in this image | Time: 0:00:37 | Telemetry: lat=37.77860, lon=-122.41570, alt=100.37
# Logs: gray car (conf=0.42) | BLIP: a car is seen in this image | Time: 0:00:37 | Telemetry: lat=37.77860, lon=-122.41570, alt=100.37
#
# 0: 384x640 2 cars, 86.1ms
# Speed: 3.8ms preprocess, 86.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.39) | BLIP: a car is seen in this image | Time: 0:00:38 | Telemetry: lat=37.77870, lon=-122.41560, alt=100.38
# Logs: gray car (conf=0.37) | BLIP: a white car is parked in the dark | Time: 0:00:38 | Telemetry: lat=37.77870, lon=-122.41560, alt=100.38
#
# 0: 384x640 1 car, 83.6ms
# Speed: 2.5ms preprocess, 83.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.47) | BLIP: a black and white photo of a car | Time: 0:00:39 | Telemetry: lat=37.77880, lon=-122.41550, alt=100.39
#
# 0: 384x640 1 car, 80.4ms
# Speed: 2.7ms preprocess, 80.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.46) | BLIP: a car is seen in this image | Time: 0:00:40 | Telemetry: lat=37.77890, lon=-122.41540, alt=100.40
#
# 0: 384x640 1 car, 85.2ms
# Speed: 2.6ms preprocess, 85.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.58) | BLIP: a blur of a car driving down a street | Time: 0:00:41 | Telemetry: lat=37.77900, lon=-122.41530, alt=100.41
#
# 0: 384x640 1 car, 92.3ms
# Speed: 3.0ms preprocess, 92.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.70) | BLIP: a car is shown in this image | Time: 0:00:42 | Telemetry: lat=37.77910, lon=-122.41520, alt=100.42
#
# 0: 384x640 1 car, 84.9ms
# Speed: 2.4ms preprocess, 84.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.69) | BLIP: a car is seen in this image | Time: 0:00:43 | Telemetry: lat=37.77920, lon=-122.41510, alt=100.43
#
# 0: 384x640 1 car, 98.1ms
# Speed: 3.2ms preprocess, 98.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.62) | BLIP: a car driving down a road with a blur | Time: 0:00:44 | Telemetry: lat=37.77930, lon=-122.41500, alt=100.44
#
# 0: 384x640 1 car, 87.7ms
# Speed: 3.6ms preprocess, 87.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.59) | BLIP: a car driving down a road with a sign on it | Time: 0:00:45 | Telemetry: lat=37.77940, lon=-122.41490, alt=100.45
#
# 0: 384x640 1 car, 106.9ms
# Speed: 2.3ms preprocess, 106.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.53) | BLIP: a car driving down a road with a blue sky background | Time: 0:00:46 | Telemetry: lat=37.77950, lon=-122.41480, alt=100.46
#
# 0: 384x640 2 cars, 75.2ms
# Speed: 2.8ms preprocess, 75.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.87) | BLIP: a blue truck driving down a road | Time: 0:00:47 | Telemetry: lat=37.77960, lon=-122.41470, alt=100.47
# Logs: gray car (conf=0.42) | BLIP: a white car is seen in this image | Time: 0:00:47 | Telemetry: lat=37.77960, lon=-122.41470, alt=100.47
#
# 0: 384x640 1 car, 84.1ms
# Speed: 4.5ms preprocess, 84.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.30) | BLIP: a blue van driving down a street | Time: 0:00:48 | Telemetry: lat=37.77970, lon=-122.41460, alt=100.48
#
# 0: 384x640 (no detections), 97.5ms
# Speed: 2.3ms preprocess, 97.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 82.4ms
# Speed: 5.4ms preprocess, 82.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 train, 80.4ms
# Speed: 2.5ms preprocess, 80.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.31) | BLIP: a car is seen in this image | Time: 0:00:51 | Telemetry: lat=37.78000, lon=-122.41430, alt=100.51
#
# 0: 384x640 1 car, 87.1ms
# Speed: 3.1ms preprocess, 87.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.70) | BLIP: a car is seen in this image | Time: 0:00:52 | Telemetry: lat=37.78010, lon=-122.41420, alt=100.52
#
# 0: 384x640 1 car, 82.4ms
# Speed: 2.8ms preprocess, 82.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.49) | BLIP: a car is seen in this image | Time: 0:00:53 | Telemetry: lat=37.78020, lon=-122.41410, alt=100.53
#
# 0: 384x640 1 car, 111.4ms
# Speed: 3.5ms preprocess, 111.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.80) | BLIP: a white car is shown in the dark | Time: 0:00:54 | Telemetry: lat=37.78030, lon=-122.41400, alt=100.54
#
# 0: 384x640 1 car, 72.4ms
# Speed: 2.4ms preprocess, 72.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.58) | BLIP: a car driving down a street at night | Time: 0:00:55 | Telemetry: lat=37.78040, lon=-122.41390, alt=100.55
#
# 0: 384x640 1 car, 107.2ms
# Speed: 2.8ms preprocess, 107.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.52) | BLIP: a car driving down a road with a blur | Time: 0:00:56 | Telemetry: lat=37.78050, lon=-122.41380, alt=100.56
#
# 0: 384x640 2 cars, 90.3ms
# Speed: 2.7ms preprocess, 90.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.79) | BLIP: a car driving down a road with a light on it | Time: 0:00:57 | Telemetry: lat=37.78060, lon=-122.41370, alt=100.57
# Logs: gray car (conf=0.33) | BLIP: a white truck parked in a parking lot | Time: 0:00:57 | Telemetry: lat=37.78060, lon=-122.41370, alt=100.57
#
# 0: 384x640 1 car, 73.0ms
# Speed: 3.1ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.85) | BLIP: a car driving down a road with a white car | Time: 0:00:58 | Telemetry: lat=37.78070, lon=-122.41360, alt=100.58
#
# 0: 384x640 1 car, 76.8ms
# Speed: 2.3ms preprocess, 76.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.31) | BLIP: a white car is seen in this image | Time: 0:00:59 | Telemetry: lat=37.78080, lon=-122.41350, alt=100.59
#
# 0: 384x640 2 cars, 97.1ms
# Speed: 3.6ms preprocess, 97.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.33) | BLIP: the car is seen in this image | Time: 0:01:00 | Telemetry: lat=37.78090, lon=-122.41340, alt=100.60
# Logs: gray car (conf=0.31) | BLIP: a white car is driving down the street | Time: 0:01:00 | Telemetry: lat=37.78090, lon=-122.41340, alt=100.60
#
# 0: 384x640 2 cars, 89.9ms
# Speed: 3.3ms preprocess, 89.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.69) | BLIP: a white car is shown in this image | Time: 0:01:01 | Telemetry: lat=37.78100, lon=-122.41330, alt=100.61
# Logs: gray car (conf=0.52) | BLIP: a white car driving down a street | Time: 0:01:01 | Telemetry: lat=37.78100, lon=-122.41330, alt=100.61
#
# 0: 384x640 2 cars, 99.6ms
# Speed: 3.4ms preprocess, 99.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.74) | BLIP: a car is seen in this image | Time: 0:01:02 | Telemetry: lat=37.78110, lon=-122.41320, alt=100.62
# Logs: gray car (conf=0.47) | BLIP: a white car driving down a road | Time: 0:01:02 | Telemetry: lat=37.78110, lon=-122.41320, alt=100.62
#
# 0: 384x640 2 cars, 132.9ms
# Speed: 2.4ms preprocess, 132.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.83) | BLIP: a car is seen in this image | Time: 0:01:03 | Telemetry: lat=37.78120, lon=-122.41310, alt=100.63
# Logs: gray car (conf=0.56) | BLIP: a white car driving down a road | Time: 0:01:03 | Telemetry: lat=37.78120, lon=-122.41310, alt=100.63
#
# 0: 384x640 2 cars, 134.2ms
# Speed: 4.7ms preprocess, 134.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.80) | BLIP: a car driving down a road with a blur | Time: 0:01:04 | Telemetry: lat=37.78130, lon=-122.41300, alt=100.64
# Logs: gray car (conf=0.45) | BLIP: a white van is driving down the road | Time: 0:01:04 | Telemetry: lat=37.78130, lon=-122.41300, alt=100.64
#
# 0: 384x640 2 cars, 75.6ms
# Speed: 3.5ms preprocess, 75.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.82) | BLIP: a silver car driving down a road | Time: 0:01:05 | Telemetry: lat=37.78140, lon=-122.41290, alt=100.65
# Logs: gray car (conf=0.41) | BLIP: a white car driving down a street | Time: 0:01:05 | Telemetry: lat=37.78140, lon=-122.41290, alt=100.65
#
# 0: 384x640 3 cars, 94.4ms
# Speed: 3.9ms preprocess, 94.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.72) | BLIP: a car is seen in this image | Time: 0:01:06 | Telemetry: lat=37.78150, lon=-122.41280, alt=100.66
# Logs: gray car (conf=0.57) | BLIP: a white car with a black background | Time: 0:01:06 | Telemetry: lat=37.78150, lon=-122.41280, alt=100.66
# Logs: gray car (conf=0.49) | BLIP: a white car driving down a street | Time: 0:01:06 | Telemetry: lat=37.78150, lon=-122.41280, alt=100.66
#
# 0: 384x640 3 cars, 90.3ms
# Speed: 11.0ms preprocess, 90.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.67) | BLIP: a car driving down a street at night | Time: 0:01:07 | Telemetry: lat=37.78160, lon=-122.41270, alt=100.67
# Logs: gray car (conf=0.66) | BLIP: a white van driving down a road | Time: 0:01:07 | Telemetry: lat=37.78160, lon=-122.41270, alt=100.67
# Logs: gray car (conf=0.52) | BLIP: a white car driving down a road | Time: 0:01:07 | Telemetry: lat=37.78160, lon=-122.41270, alt=100.67
#
# 0: 384x640 3 cars, 87.6ms
# Speed: 3.2ms preprocess, 87.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.65) | BLIP: a white van driving down a road | Time: 0:01:08 | Telemetry: lat=37.78170, lon=-122.41260, alt=100.68
# Logs: gray car (conf=0.56) | BLIP: a white car driving down a race track | Time: 0:01:08 | Telemetry: lat=37.78170, lon=-122.41260, alt=100.68
# Logs: gray car (conf=0.38) | BLIP: a car driving down a street at night | Time: 0:01:08 | Telemetry: lat=37.78170, lon=-122.41260, alt=100.68
#
# 0: 384x640 3 cars, 92.0ms
# Speed: 3.6ms preprocess, 92.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.62) | BLIP: a white van driving down a road | Time: 0:01:09 | Telemetry: lat=37.78180, lon=-122.41250, alt=100.69
# Logs: gray car (conf=0.57) | BLIP: a car driving down a street at night | Time: 0:01:09 | Telemetry: lat=37.78180, lon=-122.41250, alt=100.69
# Logs: gray car (conf=0.57) | BLIP: a white truck driving down a road | Time: 0:01:09 | Telemetry: lat=37.78180, lon=-122.41250, alt=100.69
#
# 0: 384x640 3 cars, 92.7ms
# Speed: 2.7ms preprocess, 92.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.67) | BLIP: a car driving down a road with a light on it | Time: 0:01:10 | Telemetry: lat=37.78190, lon=-122.41240, alt=100.70
# Logs: gray car (conf=0.52) | BLIP: a white car driving down a road | Time: 0:01:10 | Telemetry: lat=37.78190, lon=-122.41240, alt=100.70
# Logs: gray car (conf=0.43) | BLIP: a car is seen in this image | Time: 0:01:10 | Telemetry: lat=37.78190, lon=-122.41240, alt=100.70
#
# 0: 384x640 4 cars, 78.9ms
# Speed: 2.5ms preprocess, 78.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.68) | BLIP: a car driving down a road with a blur | Time: 0:01:11 | Telemetry: lat=37.78200, lon=-122.41230, alt=100.71
# Logs: gray car (conf=0.66) | BLIP: a truck driving down a highway with a sign on it | Time: 0:01:11 | Telemetry: lat=37.78200, lon=-122.41230, alt=100.71
# Logs: gray car (conf=0.61) | BLIP: a white truck driving down a road | Time: 0:01:11 | Telemetry: lat=37.78200, lon=-122.41230, alt=100.71
# Logs: gray car (conf=0.35) | BLIP: a blurry image of a car | Time: 0:01:11 | Telemetry: lat=37.78200, lon=-122.41230, alt=100.71
#
# 0: 384x640 5 cars, 96.7ms
# Speed: 5.4ms preprocess, 96.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.69) | BLIP: the car is driving down the road | Time: 0:01:12 | Telemetry: lat=37.78210, lon=-122.41220, alt=100.72
# Logs: gray car (conf=0.45) | BLIP: a white car driving down a road | Time: 0:01:12 | Telemetry: lat=37.78210, lon=-122.41220, alt=100.72
# Logs: black car (conf=0.44) | BLIP: a truck driving down a highway with a sign | Time: 0:01:12 | Telemetry: lat=37.78210, lon=-122.41220, alt=100.72
# Logs: gray car (conf=0.42) | BLIP: a police car is parked in the parking | Time: 0:01:12 | Telemetry: lat=37.78210, lon=-122.41220, alt=100.72
# Logs: gray car (conf=0.41) | BLIP: a blur effect effect effect effect effect effect effect effect effect effect effect effect effect effect effect effect effect effect effect | Time: 0:01:12 | Telemetry: lat=37.78210, lon=-122.41220, alt=100.72
#
# 0: 384x640 4 cars, 84.6ms
# Speed: 4.0ms preprocess, 84.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Logs: black car (conf=0.67) | BLIP: a blue van driving down a street | Time: 0:01:13 | Telemetry: lat=37.78220, lon=-122.41210, alt=100.73
# Logs: gray car (conf=0.52) | BLIP: two cars driving down a road with a truck behind them | Time: 0:01:13 | Telemetry: lat=37.78220, lon=-122.41210, alt=100.73
# Logs: gray car (conf=0.48) | BLIP: a car is shown in this image | Time: 0:01:13 | Telemetry: lat=37.78220, lon=-122.41210, alt=100.73
# Logs: gray car (conf=0.45) | BLIP: a white car driving down a street | Time: 0:01:13 | Telemetry: lat=37.78220, lon=-122.41210, alt=100.73
#
# 0: 384x640 4 cars, 106.3ms
# Speed: 2.6ms preprocess, 106.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.65) | BLIP: ford ' s new eco - drive concept is a big deal | Time: 0:01:14 | Telemetry: lat=37.78230, lon=-122.41200, alt=100.74
# Logs: gray car (conf=0.44) | BLIP: a car is shown in this image | Time: 0:01:14 | Telemetry: lat=37.78230, lon=-122.41200, alt=100.74
# Logs: gray car (conf=0.40) | BLIP: the car is parked in the parking lot | Time: 0:01:14 | Telemetry: lat=37.78230, lon=-122.41200, alt=100.74
# Logs: gray car (conf=0.38) | BLIP: a white car driving down a street | Time: 0:01:14 | Telemetry: lat=37.78230, lon=-122.41200, alt=100.74
#
# 0: 384x640 2 cars, 159.5ms
# Speed: 5.6ms preprocess, 159.5ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.52) | BLIP: a white van driving down a street | Time: 0:01:15 | Telemetry: lat=37.78240, lon=-122.41190, alt=100.75
# Logs: gray car (conf=0.47) | BLIP: the bmw x1 is seen in this image | Time: 0:01:15 | Telemetry: lat=37.78240, lon=-122.41190, alt=100.75
#
# 0: 384x640 2 cars, 121.6ms
# Speed: 3.1ms preprocess, 121.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.80) | BLIP: the car is driving down the road | Time: 0:01:16 | Telemetry: lat=37.78250, lon=-122.41180, alt=100.76
# Logs: gray car (conf=0.41) | BLIP: a white car driving down a street | Time: 0:01:16 | Telemetry: lat=37.78250, lon=-122.41180, alt=100.76
#
# 0: 384x640 2 cars, 85.1ms
# Speed: 3.2ms preprocess, 85.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.61) | BLIP: the front end of a car with a white light on it | Time: 0:01:17 | Telemetry: lat=37.78260, lon=-122.41170, alt=100.77
# Logs: gray car (conf=0.32) | BLIP: a white car driving down a road | Time: 0:01:17 | Telemetry: lat=37.78260, lon=-122.41170, alt=100.77
#
# 0: 384x640 2 cars, 113.7ms
# Speed: 4.5ms preprocess, 113.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.80) | BLIP: the front of a blue car driving down a road | Time: 0:01:18 | Telemetry: lat=37.78270, lon=-122.41160, alt=100.78
# Logs: gray car (conf=0.39) | BLIP: the new ford edge sport is a good looking car | Time: 0:01:18 | Telemetry: lat=37.78270, lon=-122.41160, alt=100.78
#
# 0: 384x640 2 cars, 122.8ms
# Speed: 7.8ms preprocess, 122.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Logs: black car (conf=0.75) | BLIP: the chevrolet cruz is seen in this und photo | Time: 0:01:19 | Telemetry: lat=37.78280, lon=-122.41150, alt=100.79
# Logs: gray car (conf=0.65) | BLIP: a white car driving down a street | Time: 0:01:19 | Telemetry: lat=37.78280, lon=-122.41150, alt=100.79
#
# 0: 384x640 1 car, 228.0ms
# Speed: 3.5ms preprocess, 228.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.38) | BLIP: a white car driving down a street | Time: 0:01:20 | Telemetry: lat=37.78290, lon=-122.41140, alt=100.80
#
# 0: 384x640 2 cars, 106.7ms
# Speed: 3.3ms preprocess, 106.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.73) | BLIP: a police car is parked on the side of the road | Time: 0:01:21 | Telemetry: lat=37.78300, lon=-122.41130, alt=100.81
# Logs: gray car (conf=0.43) | BLIP: the new bmw x1 | Time: 0:01:21 | Telemetry: lat=37.78300, lon=-122.41130, alt=100.81
#
# 0: 384x640 3 cars, 1 truck, 119.5ms
# Speed: 2.9ms preprocess, 119.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Logs: gray car (conf=0.77) | BLIP: a white car is seen in this image | Time: 0:01:22 | Telemetry: lat=37.78310, lon=-122.41120, alt=100.82
# Logs: gray car (conf=0.51) | BLIP: a police car is driving down the street | Time: 0:01:22 | Telemetry: lat=37.78310, lon=-122.41120, alt=100.82
# Logs: gray truck (conf=0.47) | BLIP: a police car is seen in this und - toned image | Time: 0:01:22 | Telemetry: lat=37.78310, lon=-122.41120, alt=100.82
# Logs: gray car (conf=0.37) | BLIP: a black and white photo of clouds | Time: 0:01:22 | Telemetry: lat=37.78310, lon=-122.41120, alt=100.82
#
# 0: 384x640 1 train, 126.1ms
# Speed: 7.0ms preprocess, 126.1ms inference, 16.1ms postprocess per image at shape (1, 3, 384, 640)
# Video analysis complete.

# %%
# 6) QUERY FUNCTIONS
def query_detections_by_label(label, db_name=DB_NAME):
    conn = sqlite3.connect(db_name)
    c = conn.cursor()
    query = """
        SELECT detection_id, timestamp, yolo_label, color, confidence, blip_caption 
        FROM detections 
        WHERE yolo_label = ?
    """
    c.execute(query, (label,))
    rows = c.fetchall()
    conn.close()
    return rows

def query_detections_by_color(color, db_name=DB_NAME):
    conn = sqlite3.connect(db_name)
    c = conn.cursor()
    query = """
        SELECT detection_id, timestamp, yolo_label, color, confidence, blip_caption 
        FROM detections 
        WHERE color = ?
    """
    c.execute(query, (color,))
    rows = c.fetchall()
    conn.close()
    return rows

def query_alerts(db_name=DB_NAME):
    """
    Fetch all generated alerts.
    """
    conn = sqlite3.connect(db_name)
    c = conn.cursor()
    c.execute("SELECT alert_id, timestamp, alert_message FROM alerts")
    rows = c.fetchall()
    conn.close()
    return rows

def query_telemetry(db_name=DB_NAME):
    """
    Fetch all telemetry records.
    """
    conn = sqlite3.connect(db_name)
    c = conn.cursor()
    c.execute("SELECT telemetry_id, timestamp, latitude, longitude, altitude FROM telemetry")
    rows = c.fetchall()
    conn.close()
    return rows

# Example usage:
print("\nAll cars detected:")
car_rows = query_detections_by_label("car")
for row in car_rows:
    print(row)

print("\nAll silver vehicles detected:")
silver_rows = query_detections_by_color("silver")
for row in silver_rows:
    print(row)

print("\nAll alerts generated:")
alert_rows = query_alerts()
for row in alert_rows:
    print(row)

print("\nAll telemetry records (first 5 shown):")
telemetry_rows = query_telemetry()
for row in telemetry_rows[:5]:
    print(row)

# 7) QA & TEST CASES
def test_detections_logged(db_name=DB_NAME):
    conn = sqlite3.connect(db_name)
    c = conn.cursor()
    c.execute("SELECT COUNT(*) FROM detections")
    count = c.fetchone()[0]
    conn.close()
    if count == 0:
        print("Test Failed: No detections found in DB.")
    else:
        print(f"Test Passed: {count} detections found in DB.")

# Run QA
test_detections_logged()
# Out:
# All cars detected:
# (1, '0', 'car', 'gray', 0.7188957929611206, 'a car driving down a road with a sign on it')
# (2, '0', 'car', 'black', 0.5435592532157898, 'a blue car driving down a road')
# (3, '0', 'car', 'gray', 0.4004042446613312, 'a truck driving down a highway with a red light')
# (4, '0', 'car', 'black', 0.8175540566444397, 'a car driving down a road with a sign on the side')
# (5, '0', 'car', 'gray', 0.42921680212020874, 'a bus is driving down the road')
# (6, '0', 'car', 'silver', 0.31140992045402527, 'a white van parked in a parking lot')
# (7, '1', 'car', 'black', 0.6088934540748596, 'a car driving down a road with a person in the back')
# (8, '1', 'car', 'gray', 0.3537733852863312, 'a white van is parked in the dark')
# (10, '2', 'car', 'gray', 0.40786299109458923, 'a white van is parked in the dark')
# (11, '2', 'car', 'gray', 0.3873065114021301, 'a truck with a yellow cab and a black cab')
# (13, '3', 'car', 'gray', 0.6460999250411987, 'the bmw x6 is seen in this aerial image')
# (14, '3', 'car', 'gray', 0.5461740493774414, 'a white car driving down a street')
# (15, '3', 'car', 'gray', 0.36729228496551514, 'a yellow van driving down a street next to a building')
# (16, '4', 'car', 'gray', 0.6298252940177917, 'a car driving down a road with a police car behind it')
# (17, '4', 'car', 'gray', 0.41278138756752014, 'a car is seen in this image from the video')
# (18, '4', 'car', 'gray', 0.3878718316555023, 'a school bus driving down a street')
# (20, '5', 'car', 'gray', 0.6390402317047119, 'a white car driving down a street')
# (21, '5', 'car', 'gray', 0.6246387958526611, 'a car driving down a road with a light on it')
# (22, '5', 'car', 'black', 0.6186571717262268, 'a car is seen in this image')
# (23, '5', 'car', 'gray', 0.4801980257034302, 'a white van driving down a road')
# (24, '5', 'car', 'gray', 0.4302593767642975, 'a school bus with a yellow top')
# (26, '6', 'car', 'gray', 0.8478104472160339, 'a car driving down a street in the city')
# (27, '6', 'car', 'gray', 0.7509238719940186, 'a white van with red roof and a red roof')
# (28, '6', 'car', 'gray', 0.6528028249740601, 'a red van driving down a road with smoke in the background')
# (29, '6', 'car', 'gray', 0.6432852149009705, 'a white car driving down a road')
# (30, '6', 'car', 'black', 0.5446382761001587, 'a car is seen in this image')
# (31, '7', 'car', 'gray', 0.6554878354072571, 'the car is seen in this image')
# (32, '7', 'car', 'gray', 0.6506228446960449, 'a red car with a black background')
# (33, '7', 'car', 'black', 0.6069099307060242, 'a car driving down the road at night')
# (34, '7', 'car', 'gray', 0.6025635600090027, 'a car is parked in the parking lot')
# (35, '7', 'car', 'gray', 0.45344287157058716, 'a car driving down a road with a sign on the back')
# (36, '7', 'car', 'gray', 0.4448326528072357, 'a red van driving down a road')
# (37, '8', 'car', 'gray', 0.7030761241912842, 'a white car driving down a road')
# (38, '8', 'car', 'gray', 0.6895593404769897, 'a car is seen in this image')
# (39, '8', 'car', 'gray', 0.6230044960975647, 'a red van is driving down the street')
# (40, '8', 'car', 'gray', 0.48602765798568726, "a car with a white light on it ' s hood")
# (41, '8', 'car', 'gray', 0.4624696671962738, 'a car driving down the road')
# (42, '8', 'car', 'gray', 0.4044418931007385, 'a car driving down a road with fog')
# (43, '9', 'car', 'black', 0.7791615724563599, 'a car driving down a street with a white line')
# (44, '9', 'car', 'gray', 0.723231315612793, 'a car driving down a road with a white car')
# (45, '9', 'car', 'black', 0.7000302672386169, 'a car driving down a road with a sign')
# (46, '9', 'car', 'gray', 0.6609117388725281, 'a car is parked in a parking lot')
# (47, '9', 'car', 'gray', 0.6152299642562866, 'a car with a black hood and a white hood')
# (48, '9', 'car', 'gray', 0.5946605205535889, 'a car driving down a street at night')
# (49, '9', 'car', 'gray', 0.46865448355674744, 'a car is seen through a window in this und photo')
# (50, '9', 'car', 'gray', 0.3755607604980469, 'a car is shown in this image')
# (51, '10', 'car', 'black', 0.7652798891067505, 'a car driving down a road with a white sign')
# (52, '10', 'car', 'gray', 0.7140951752662659, 'a white car driving down a road')
# (53, '10', 'car', 'black', 0.632916271686554, 'the police car is seen in this image')
# (54, '10', 'car', 'gray', 0.5670443773269653, 'a car is parked in a parking lot')
# (55, '10', 'car', 'gray', 0.4390653073787689, 'a car driving down a road at night')
# (56, '10', 'car', 'gray', 0.38598397374153137, 'a police car is seen in this und photo')
# (57, '10', 'car', 'gray', 0.3247765302658081, 'a white bus is driving down the road')
# (58, '11', 'car', 'black', 0.8080179691314697, 'a car driving down a road with a sign on it')
# (59, '11', 'car', 'gray', 0.7590484023094177, 'a white car driving down a highway')
# (60, '11', 'car', 'black', 0.6658801436424255, 'a car driving down a street with a light on it')
# (61, '11', 'car', 'gray', 0.5484513640403748, 'a car driving down a road at night')
# (62, '11', 'car', 'gray', 0.5403798818588257, 'a car driving down a street with a blue light')
# (63, '11', 'car', 'gray', 0.44820937514305115, 'the car is seen in this image')
# (64, '11', 'car', 'gray', 0.39217934012413025, 'a white van is driving down the street')
# (65, '12', 'car', 'gray', 0.8089596033096313, 'a white car driving down a road')
# (66, '12', 'car', 'black', 0.8012427687644958, 'a car driving down a road with a blue car')
# (67, '12', 'car', 'gray', 0.6392339468002319, 'a car driving down a highway')
# (68, '12', 'car', 'gray', 0.6047242879867554, 'a car driving down a road with a person in the back')
# (69, '12', 'car', 'gray', 0.5427026748657227, 'a car is seen from above as it drives down a road')
# (70, '12', 'car', 'black', 0.5271718502044678, 'a car driving down a road with fog')
# (71, '12', 'car', 'gray', 0.5172337293624878, 'a car is seen in this image')
# (72, '12', 'car', 'gray', 0.49630266427993774, 'a white van driving down a street')
# (73, '13', 'car', 'gray', 0.7135044932365417, 'a car is parked in a parking lot')
# (74, '13', 'car', 'gray', 0.6528957486152649, 'a car parked in a parking lot')
# (75, '13', 'car', 'gray', 0.6221506595611572, 'a car is seen in this image')
# (76, '13', 'car', 'gray', 0.6120410561561584, 'a car driving down a road with a person in the passenger seat')
# (78, '13', 'car', 'black', 0.5398971438407898, 'the new chevrolet camaro is a new car that will be available in the us')
# (79, '13', 'car', 'gray', 0.4634455740451813, 'a white van is driving down the road')
# (80, '14', 'car', 'gray', 0.7845830321311951, 'a car is seen in this und photo')
# (81, '14', 'car', 'gray', 0.5286439061164856, 'a white car parked in a parking lot')
# (82, '14', 'car', 'gray', 0.3418675661087036, 'a white van driving down a road')
# (83, '15', 'car', 'gray', 0.7359768152236938, 'a car is driving down the street in the dark')
# (84, '15', 'car', 'gray', 0.5644795298576355, 'a car with a white hood and hood on')
# (86, '15', 'car', 'gray', 0.4124249219894409, 'a white car driving down a street')
# (88, '16', 'car', 'gray', 0.7505694627761841, 'a car is driving down the street in a parking lot')
# (89, '16', 'car', 'gray', 0.6419153809547424, 'a white van driving down a road next to a building')
# (90, '16', 'car', 'gray', 0.6160014271736145, 'a white car driving down a street')
# (92, '16', 'car', 'gray', 0.41757428646087646, 'a car is shown in this image')
# (95, '17', 'car', 'gray', 0.7282055616378784, 'a white car driving down a street')
# (96, '17', 'car', 'gray', 0.5795328617095947, 'a car is seen in this image')
# (98, '17', 'car', 'gray', 0.4172338843345642, 'a white van driving down a road next to a building')
# (99, '17', 'car', 'gray', 0.3213818073272705, 'a car is seen in this image')
# (101, '17', 'car', 'gray', 0.316281259059906, 'a blurry image of a cloud')
# (102, '18', 'car', 'gray', 0.7664296627044678, 'a white car driving down a street')
# (103, '18', 'car', 'gray', 0.7018486857414246, 'a car is seen in this image from the video')
# (105, '18', 'car', 'gray', 0.5383476614952087, 'a white van driving down a road')
# (107, '18', 'car', 'gray', 0.38182783126831055, 'a car is parked in the dark')
# (109, '19', 'car', 'gray', 0.715054452419281, 'a car is seen in this image')
# (110, '19', 'car', 'gray', 0.7143334746360779, 'a white car driving down a street')
# (113, '20', 'car', 'gray', 0.8435839414596558, 'a white car driving down a road')
# (114, '20', 'car', 'gray', 0.7015162706375122, 'a car is seen in this image')
# (116, '21', 'car', 'gray', 0.7582324743270874, 'a car is driving down the road with a police car behind it')
# (117, '21', 'car', 'gray', 0.3809334933757782, 'a blurry image of a car in the dark')
# (118, '21', 'car', 'gray', 0.37272512912750244, 'a black and white photo of a man in a suit')
# (119, '22', 'car', 'gray', 0.7152746915817261, 'a white truck driving down a road')
# (120, '22', 'car', 'gray', 0.42074573040008545, 'a blurry image of a car')
# (121, '22', 'car', 'gray', 0.34607046842575073, 'a blurry image of a cloud in the sky')
# (122, '23', 'car', 'gray', 0.3927311301231384, 'the police car is seen in this und photo')
# (123, '23', 'car', 'gray', 0.3275609314441681, 'a blurry image of a car in the dark')
# (124, '24', 'car', 'gray', 0.5298087000846863, 'a blurry image of a person in a car')
# (125, '25', 'car', 'gray', 0.5661106109619141, 'the gmc is seen in this und photo')
# (126, '25', 'car', 'gray', 0.49895957112312317, 'a blurry image of a car in the dark')
# (128, '26', 'car', 'gray', 0.42448171973228455, 'a truck is driving down the road in the snow')
# (129, '26', 'car', 'gray', 0.41107481718063354, 'a blurry image of a car in the dark')
# (131, '26', 'car', 'gray', 0.3078918755054474, 'a blurry image of a cloud')
# (132, '27', 'car', 'black', 0.49227428436279297, 'a car driving down a road with a person in the back')
# (134, '28', 'car', 'gray', 0.6246209144592285, 'a car is driving down the road in the tunnel')
# (135, '28', 'car', 'gray', 0.4300440549850464, 'a car is seen in this surveillance image')
# (136, '29', 'car', 'gray', 0.620444655418396, 'a car is driving down the street in a parking lot')
# (138, '29', 'car', 'gray', 0.33709776401519775, 'a police car is seen in this und photo')
# (139, '30', 'car', 'gray', 0.7439365983009338, 'a car is seen in this image from the video')
# (140, '30', 'car', 'gray', 0.6929879188537598, 'a car is driving down the road with other cars')
# (141, '30', 'car', 'gray', 0.48554378747940063, 'the car is parked in the parking lot')
# (142, '30', 'car', 'gray', 0.44747495651245117, 'a car is seen in this und photo')
# (143, '31', 'car', 'gray', 0.6506063938140869, 'a car is parked in a parking lot')
# (144, '31', 'car', 'gray', 0.6293155550956726, 'a car driving down a street with a sign on it')
# (145, '31', 'car', 'gray', 0.5491231679916382, 'a car is seen in this image from the back')
# (146, '31', 'car', 'gray', 0.48001161217689514, 'a police car is seen in this und photo')
# (148, '31', 'car', 'gray', 0.3831355571746826, 'a blurry image of a cloud')
# (150, '31', 'car', 'gray', 0.36314383149147034, 'a police car driving down the road')
# (151, '32', 'car', 'gray', 0.7608782649040222, 'a car driving down a street with a red car')
# (152, '32', 'car', 'gray', 0.677401602268219, 'a white car is driving down the street')
# (153, '32', 'car', 'gray', 0.6582733988761902, 'a police car is seen on the side of a road')
# (154, '32', 'car', 'gray', 0.5776978135108948, 'a car is seen in this image')
# (155, '32', 'car', 'gray', 0.4246801733970642, 'a car is parked in a parking lot')
# (156, '32', 'car', 'gray', 0.37870460748672485, 'a blurry image of a cloud')
# (157, '33', 'car', 'gray', 0.7832725048065186, 'a red car driving down a street')
# (158, '33', 'car', 'gray', 0.7078946232795715, 'a car is seen in this image')
# (159, '33', 'car', 'gray', 0.5697166919708252, 'a car is shown in this image')
# (160, '33', 'car', 'gray', 0.5262084007263184, 'a police car is seen in this image')
# (161, '33', 'car', 'gray', 0.43194958567619324, 'a police car is seen on the side of a road')
# (162, '33', 'car', 'gray', 0.3877556622028351, 'a blurry image of a city')
# (163, '34', 'car', 'gray', 0.8426043391227722, 'a car is seen in this image from the video')
# (164, '34', 'car', 'gray', 0.5793893933296204, 'a car is seen in this image')
# (165, '34', 'car', 'gray', 0.47723013162612915, 'a white car is parked in a parking lot')
# (166, '34', 'car', 'gray', 0.33353742957115173, 'a blurry image of a car')
# (167, '34', 'car', 'gray', 0.3086562156677246, 'a police car is seen in this und photo')
# (168, '35', 'car', 'gray', 0.8017184734344482, 'a car is seen in this image')
# (169, '35', 'car', 'gray', 0.5197852849960327, 'a car is seen in this image')
# (170, '35', 'car', 'gray', 0.3951174318790436, 'a man in a black shirt and black pants')
# (171, '36', 'car', 'gray', 0.5813838839530945, 'a car is seen in this image')
# (172, '36', 'car', 'gray', 0.49330219626426697, 'a blur of a car driving down a road')
# (173, '36', 'car', 'gray', 0.3941221535205841, 'a computer screen with a black background')
# (174, '37', 'car', 'gray', 0.4868899881839752, 'a car is seen in this image')
# (175, '37', 'car', 'gray', 0.4218451976776123, 'a car is seen in this image')
# (176, '38', 'car', 'gray', 0.3933236300945282, 'a car is seen in this image')
# (177, '38', 'car', 'gray', 0.3707118034362793, 'a white car is parked in the dark')
# (178, '39', 'car', 'gray', 0.4670282304286957, 'a black and white photo of a car')
# (179, '40', 'car', 'gray', 0.4592472314834595, 'a car is seen in this image')
# (180, '41', 'car', 'gray', 0.5847542881965637, 'a blur of a car driving down a street')
# (181, '42', 'car', 'gray', 0.6987511515617371, 'a car is shown in this image')
# (182, '43', 'car', 'gray', 0.6859782934188843, 'a car is seen in this image')
# (183, '44', 'car', 'gray', 0.6244880557060242, 'a car driving down a road with a blur')
# (184, '45', 'car', 'gray', 0.5887666344642639, 'a car driving down a road with a sign on it')
# (185, '46', 'car', 'gray', 0.5305317044258118, 'a car driving down a road with a blue sky background')
# (186, '47', 'car', 'gray', 0.8719882369041443, 'a blue truck driving down a road')
# (187, '47', 'car', 'gray', 0.4243524968624115, 'a white car is seen in this image')
# (188, '48', 'car', 'gray', 0.3006395697593689, 'a blue van driving down a street')
# (190, '51', 'car', 'gray', 0.30659112334251404, 'a car is seen in this image')
# (191, '52', 'car', 'gray', 0.6990445256233215, 'a car is seen in this image')
# (192, '53', 'car', 'gray', 0.487071692943573, 'a car is seen in this image')
# (193, '54', 'car', 'gray', 0.8020655512809753, 'a white car is shown in the dark')
# (194, '55', 'car', 'gray', 0.5774593949317932, 'a car driving down a street at night')
# (195, '56', 'car', 'gray', 0.5193118453025818, 'a car driving down a road with a blur')
# (196, '57', 'car', 'gray', 0.7914548516273499, 'a car driving down a road with a light on it')
# (197, '57', 'car', 'gray', 0.333867609500885, 'a white truck parked in a parking lot')
# (198, '58', 'car', 'gray', 0.8488995432853699, 'a car driving down a road with a white car')
# (199, '59', 'car', 'gray', 0.3126083314418793, 'a white car is seen in this image')
# (200, '60', 'car', 'gray', 0.3306126892566681, 'the car is seen in this image')
# (201, '60', 'car', 'gray', 0.3139011859893799, 'a white car is driving down the street')
# (202, '61', 'car', 'gray', 0.6864906549453735, 'a white car is shown in this image')
# (203, '61', 'car', 'gray', 0.5223464965820312, 'a white car driving down a street')
# (204, '62', 'car', 'gray', 0.739564061164856, 'a car is seen in this image')
# (205, '62', 'car', 'gray', 0.4739816188812256, 'a white car driving down a road')
# (206, '63', 'car', 'gray', 0.8258854746818542, 'a car is seen in this image')
# (207, '63', 'car', 'gray', 0.5550389289855957, 'a white car driving down a road')
# (208, '64', 'car', 'gray', 0.7955560684204102, 'a car driving down a road with a blur')
# (209, '64', 'car', 'gray', 0.4460948407649994, 'a white van is driving down the road')
# (210, '65', 'car', 'gray', 0.8242030143737793, 'a silver car driving down a road')
# (211, '65', 'car', 'gray', 0.4056893289089203, 'a white car driving down a street')
# (212, '66', 'car', 'gray', 0.7190529108047485, 'a car is seen in this image')
# (213, '66', 'car', 'gray', 0.5686745643615723, 'a white car with a black background')
# (214, '66', 'car', 'gray', 0.487148642539978, 'a white car driving down a street')
# (215, '67', 'car', 'gray', 0.6709322929382324, 'a car driving down a street at night')
# (216, '67', 'car', 'gray', 0.6579771637916565, 'a white van driving down a road')
# (217, '67', 'car', 'gray', 0.5202076435089111, 'a white car driving down a road')
# (218, '68', 'car', 'gray', 0.6489320993423462, 'a white van driving down a road')
# (219, '68', 'car', 'gray', 0.5567857623100281, 'a white car driving down a race track')
# (220, '68', 'car', 'gray', 0.3823032081127167, 'a car driving down a street at night')
# (221, '69', 'car', 'gray', 0.617759108543396, 'a white van driving down a road')
# (222, '69', 'car', 'gray', 0.5732787251472473, 'a car driving down a street at night')
# (223, '69', 'car', 'gray', 0.5655199885368347, 'a white truck driving down a road')
# (224, '70', 'car', 'gray', 0.6717982292175293, 'a car driving down a road with a light on it')
# (225, '70', 'car', 'gray', 0.5244522094726562, 'a white car driving down a road')
# (226, '70', 'car', 'gray', 0.43244701623916626, 'a car is seen in this image')
# (227, '71', 'car', 'gray', 0.6794835329055786, 'a car driving down a road with a blur')
# (228, '71', 'car', 'gray', 0.6601799130439758, 'a truck driving down a highway with a sign on it')
# (229, '71', 'car', 'gray', 0.6054019331932068, 'a white truck driving down a road')
# (230, '71', 'car', 'gray', 0.35177236795425415, 'a blurry image of a car')
# (231, '72', 'car', 'gray', 0.689186692237854, 'the car is driving down the road')
# (232, '72', 'car', 'gray', 0.44958987832069397, 'a white car driving down a road')
# (233, '72', 'car', 'black', 0.4422805607318878, 'a truck driving down a highway with a sign')
# (234, '72', 'car', 'gray', 0.4192274212837219, 'a police car is parked in the parking')
# (235, '72', 'car', 'gray', 0.41153380274772644, 'a blur effect effect effect effect effect effect effect effect effect effect effect effect effect effect effect effect effect effect effect')
# (236, '73', 'car', 'black', 0.6650204658508301, 'a blue van driving down a street')
# (237, '73', 'car', 'gray', 0.5160906314849854, 'two cars driving down a road with a truck behind them')
# (238, '73', 'car', 'gray', 0.48434916138648987, 'a car is shown in this image')
# (239, '73', 'car', 'gray', 0.4490099251270294, 'a white car driving down a street')
# (240, '74', 'car', 'gray', 0.6482304930686951, "ford ' s new eco - drive concept is a big deal")
# (241, '74', 'car', 'gray', 0.44100117683410645, 'a car is shown in this image')
# (242, '74', 'car', 'gray', 0.4016590714454651, 'the car is parked in the parking lot')
# (243, '74', 'car', 'gray', 0.37518826127052307, 'a white car driving down a street')
# (244, '75', 'car', 'gray', 0.5209581255912781, 'a white van driving down a street')
# (245, '75', 'car', 'gray', 0.4692906439304352, 'the bmw x1 is seen in this image')
# (246, '76', 'car', 'gray', 0.8009986877441406, 'the car is driving down the road')
# (247, '76', 'car', 'gray', 0.4128139317035675, 'a white car driving down a street')
# (248, '77', 'car', 'gray', 0.6138134002685547, 'the front end of a car with a white light on it')
# (249, '77', 'car', 'gray', 0.3203340768814087, 'a white car driving down a road')
# (250, '78', 'car', 'gray', 0.795462429523468, 'the front of a blue car driving down a road')
# (251, '78', 'car', 'gray', 0.3938373029232025, 'the new ford edge sport is a good looking car')
# (252, '79', 'car', 'black', 0.7474921941757202, 'the chevrolet cruz is seen in this und photo')
# (253, '79', 'car', 'gray', 0.6470067501068115, 'a white car driving down a street')
# (254, '80', 'car', 'gray', 0.383280873298645, 'a white car driving down a street')
# (255, '81', 'car', 'gray', 0.7280154824256897, 'a police car is parked on the side of the road')
# (256, '81', 'car', 'gray', 0.4324589967727661, 'the new bmw x1')
# (257, '82', 'car', 'gray', 0.7672587037086487, 'a white car is seen in this image')
# (258, '82', 'car', 'gray', 0.5073128342628479, 'a police car is driving down the street')
# (260, '82', 'car', 'gray', 0.3682986795902252, 'a black and white photo of clouds')
# (262, '0:00:00', 'car', 'gray', 0.7188957929611206, 'a car driving down a road with a sign on it')
# (263, '0:00:00', 'car', 'black', 0.5435592532157898, 'a blue car driving down a road')
# (264, '0:00:00', 'car', 'gray', 0.4004042446613312, 'a truck driving down a highway with a red light')
# (265, '0:00:00', 'car', 'black', 0.8175540566444397, 'a car driving down a road with a sign on the side')
# (266, '0:00:00', 'car', 'gray', 0.42921680212020874, 'a bus is driving down the road')
# (267, '0:00:00', 'car', 'silver', 0.31140992045402527, 'a white van parked in a parking lot')
# (268, '0:00:01', 'car', 'black', 0.6088934540748596, 'a car driving down a road with a person in the back')
# (269, '0:00:01', 'car', 'gray', 0.3537733852863312, 'a white van is parked in the dark')
# (271, '0:00:02', 'car', 'gray', 0.40786299109458923, 'a white van is parked in the dark')
# (272, '0:00:02', 'car', 'gray', 0.3873065114021301, 'a truck with a yellow cab and a black cab')
# (274, '0:00:03', 'car', 'gray', 0.6460999250411987, 'the bmw x6 is seen in this aerial image')
# (275, '0:00:03', 'car', 'gray', 0.5461740493774414, 'a white car driving down a street')
# (276, '0:00:03', 'car', 'gray', 0.36729228496551514, 'a yellow van driving down a street next to a building')
# (277, '0:00:04', 'car', 'gray', 0.6298252940177917, 'a car driving down a road with a police car behind it')
# (278, '0:00:04', 'car', 'gray', 0.41278138756752014, 'a car is seen in this image from the video')
# (279, '0:00:04', 'car', 'gray', 0.3878718316555023, 'a school bus driving down a street')
# (281, '0:00:05', 'car', 'gray', 0.6390402317047119, 'a white car driving down a street')
# (282, '0:00:05', 'car', 'gray', 0.6246387958526611, 'a car driving down a road with a light on it')
# (283, '0:00:05', 'car', 'black', 0.6186571717262268, 'a car is seen in this image')
# (284, '0:00:05', 'car', 'gray', 0.4801980257034302, 'a white van driving down a road')
# (285, '0:00:05', 'car', 'gray', 0.4302593767642975, 'a school bus with a yellow top')
# (287, '0:00:06', 'car', 'gray', 0.8478104472160339, 'a car driving down a street in the city')
# (288, '0:00:06', 'car', 'gray', 0.7509238719940186, 'a white van with red roof and a red roof')
# (289, '0:00:06', 'car', 'gray', 0.6528028249740601, 'a red van driving down a road with smoke in the background')
# (290, '0:00:06', 'car', 'gray', 0.6432852149009705, 'a white car driving down a road')
# (291, '0:00:06', 'car', 'black', 0.5446382761001587, 'a car is seen in this image')
# (292, '0:00:07', 'car', 'gray', 0.6554878354072571, 'the car is seen in this image')
# (293, '0:00:07', 'car', 'gray', 0.6506228446960449, 'a red and white car parked in a parking lot')
# (294, '0:00:07', 'car', 'black', 0.6069099307060242, 'a car driving down the road at night')
# (295, '0:00:07', 'car', 'gray', 0.6025635600090027, 'a car is parked in the parking lot')
# (296, '0:00:07', 'car', 'gray', 0.45344287157058716, 'a car driving down a road with a sign on the back')
# (297, '0:00:07', 'car', 'gray', 0.4448326528072357, 'a red van driving down a road')
# (298, '0:00:08', 'car', 'gray', 0.7030761241912842, 'a white car driving down a road')
# (299, '0:00:08', 'car', 'gray', 0.6895593404769897, 'a car is seen in this image')
# (300, '0:00:08', 'car', 'gray', 0.6230044960975647, 'a red van is driving down the street')
# (301, '0:00:08', 'car', 'gray', 0.48602765798568726, "a car with a white light on it ' s hood")
# (302, '0:00:08', 'car', 'gray', 0.4624696671962738, 'a car driving down the road')
# (303, '0:00:08', 'car', 'gray', 0.4044418931007385, 'a car driving down a road with fog')
# (304, '0:00:09', 'car', 'black', 0.7791615724563599, 'a car driving down a street with a white line')
# (305, '0:00:09', 'car', 'gray', 0.723231315612793, 'a car driving down a road with a white car')
# (306, '0:00:09', 'car', 'black', 0.7000302672386169, 'a car driving down a road with a sign')
# (307, '0:00:09', 'car', 'gray', 0.6609117388725281, 'a car is parked in a parking lot')
# (308, '0:00:09', 'car', 'gray', 0.6152299642562866, 'a car with a black hood and a white hood')
# (309, '0:00:09', 'car', 'gray', 0.5946605205535889, 'a car driving down a street at night')
# (310, '0:00:09', 'car', 'gray', 0.46865448355674744, 'a car is seen through a window in this und photo')
# (311, '0:00:09', 'car', 'gray', 0.3755607604980469, 'a car is shown in this image')
# (312, '0:00:10', 'car', 'black', 0.7652798891067505, 'a car driving down a road with a white sign')
# (313, '0:00:10', 'car', 'gray', 0.7140951752662659, 'a white car driving down a road')
# (314, '0:00:10', 'car', 'black', 0.632916271686554, 'the police car is seen in this image')
# (315, '0:00:10', 'car', 'gray', 0.5670443773269653, 'a car is parked in a parking lot')
# (316, '0:00:10', 'car', 'gray', 0.4390653073787689, 'a car driving down a road at night')
# (317, '0:00:10', 'car', 'gray', 0.38598397374153137, 'a police car is seen in this und photo')
# (318, '0:00:10', 'car', 'gray', 0.3247765302658081, 'a white bus is driving down the road')
# (319, '0:00:11', 'car', 'black', 0.8080179691314697, 'a car driving down a road with a sign on it')
# (320, '0:00:11', 'car', 'gray', 0.7590484023094177, 'a white car driving down a highway')
# (321, '0:00:11', 'car', 'black', 0.6658801436424255, 'a car driving down a street with a light on it')
# (322, '0:00:11', 'car', 'gray', 0.5484513640403748, 'a car driving down a road at night')
# (323, '0:00:11', 'car', 'gray', 0.5403798818588257, 'a car driving down a street with a blue light')
# (324, '0:00:11', 'car', 'gray', 0.44820937514305115, 'the car is seen in this image')
# (325, '0:00:11', 'car', 'gray', 0.39217934012413025, 'a white van is driving down the street')
# (326, '0:00:12', 'car', 'gray', 0.8089596033096313, 'a white car driving down a road')
# (327, '0:00:12', 'car', 'black', 0.8012427687644958, 'a car driving down a road with a blue car')
# (328, '0:00:12', 'car', 'gray', 0.6392339468002319, 'a car driving down a highway')
# (329, '0:00:12', 'car', 'gray', 0.6047242879867554, 'a car driving down a road with a person in the back')
# (330, '0:00:12', 'car', 'gray', 0.5427026748657227, 'a car is seen from above as it drives down a road')
# (331, '0:00:12', 'car', 'black', 0.5271718502044678, 'a car driving down a road with fog')
# (332, '0:00:12', 'car', 'gray', 0.5172337293624878, 'a car is seen in this image')
# (333, '0:00:12', 'car', 'gray', 0.49630266427993774, 'a white van driving down a street')
# (334, '0:00:13', 'car', 'gray', 0.7135044932365417, 'a car is parked in a parking lot')
# (335, '0:00:13', 'car', 'gray', 0.6528957486152649, 'a car parked in a parking lot')
# (336, '0:00:13', 'car', 'gray', 0.6221506595611572, 'a car is seen in this image')
# (337, '0:00:13', 'car', 'gray', 0.6120410561561584, 'a car driving down a road with a person in the passenger seat')
# (339, '0:00:13', 'car', 'black', 0.5398971438407898, 'the new chevrolet camaro is a new car that will be available in the us')
# (340, '0:00:13', 'car', 'gray', 0.4634455740451813, 'a white van is driving down the road')
# (341, '0:00:14', 'car', 'gray', 0.7845830321311951, 'a car is seen in this und photo')
# (342, '0:00:14', 'car', 'gray', 0.5286439061164856, 'a white car parked in a parking lot')
# (343, '0:00:14', 'car', 'gray', 0.3418675661087036, 'a white van driving down a road')
# (344, '0:00:15', 'car', 'gray', 0.7359768152236938, 'a car is driving down the street in the dark')
# (345, '0:00:15', 'car', 'gray', 0.5644795298576355, 'a car with a white hood and hood on')
# (347, '0:00:15', 'car', 'gray', 0.4124249219894409, 'a white car driving down a street')
# (349, '0:00:16', 'car', 'gray', 0.7505694627761841, 'a car is driving down the street in a parking lot')
# (350, '0:00:16', 'car', 'gray', 0.6419153809547424, 'a white van driving down a road next to a building')
# (351, '0:00:16', 'car', 'gray', 0.6160014271736145, 'a white car driving down a street')
# (353, '0:00:16', 'car', 'gray', 0.41757428646087646, 'a car is shown in this image')
# (355, '0:00:17', 'car', 'gray', 0.7282055616378784, 'a white car driving down a street')
# (356, '0:00:17', 'car', 'gray', 0.5795328617095947, 'a car is seen in this image')
# (357, '0:00:17', 'car', 'gray', 0.4172338843345642, 'a white van driving down a road next to a building')
# (358, '0:00:17', 'car', 'gray', 0.3213818073272705, 'a car is seen in this image')
# (360, '0:00:17', 'car', 'gray', 0.316281259059906, 'a blurry image of a cloud')
# (361, '0:00:18', 'car', 'gray', 0.7664296627044678, 'a white car driving down a street')
# (362, '0:00:18', 'car', 'gray', 0.7018486857414246, 'a car is seen in this image from the video')
# (364, '0:00:18', 'car', 'gray', 0.5383476614952087, 'a white van driving down a road')
# (366, '0:00:18', 'car', 'gray', 0.38182783126831055, 'a car is parked in the dark')
# (368, '0:00:19', 'car', 'gray', 0.715054452419281, 'a car is seen in this image')
# (369, '0:00:19', 'car', 'gray', 0.7143334746360779, 'a white car driving down a street')
# (372, '0:00:20', 'car', 'gray', 0.8435839414596558, 'a white car driving down a road')
# (373, '0:00:20', 'car', 'gray', 0.7015162706375122, 'a car is seen in this image')
# (375, '0:00:21', 'car', 'gray', 0.7582324743270874, 'a car is driving down the road with a police car behind it')
# (376, '0:00:21', 'car', 'gray', 0.3809334933757782, 'a blurry image of a car in the dark')
# (377, '0:00:21', 'car', 'gray', 0.37272512912750244, 'a black and white photo of a man in a suit')
# (378, '0:00:22', 'car', 'gray', 0.7152746915817261, 'a white truck driving down a road')
# (379, '0:00:22', 'car', 'gray', 0.42074573040008545, 'a blurry image of a car')
# (380, '0:00:22', 'car', 'gray', 0.34607046842575073, 'a blurry image of a cloud in the sky')
# (381, '0:00:23', 'car', 'gray', 0.3927311301231384, 'the police car is seen in this und photo')
# (382, '0:00:23', 'car', 'gray', 0.3275609314441681, 'a blurry image of a car in the dark')
# (383, '0:00:24', 'car', 'gray', 0.5298087000846863, 'a blurry image of a person in a car')
# (384, '0:00:25', 'car', 'gray', 0.5661106109619141, 'the gmc is seen in this und photo')
# (385, '0:00:25', 'car', 'gray', 0.49895957112312317, 'a blurry image of a car in the dark')
# (387, '0:00:26', 'car', 'gray', 0.42448171973228455, 'a truck is driving down the road in the snow')
# (388, '0:00:26', 'car', 'gray', 0.41107481718063354, 'a blurry image of a car in the dark')
# (390, '0:00:26', 'car', 'gray', 0.3078918755054474, 'a blurry image of a cloud')
# (391, '0:00:27', 'car', 'black', 0.49227428436279297, 'a car driving down a road with a person in the back')
# (393, '0:00:28', 'car', 'gray', 0.6246209144592285, 'a car is driving down the road in the tunnel')
# (394, '0:00:28', 'car', 'gray', 0.4300440549850464, 'a car is seen in this surveillance image')
# (395, '0:00:29', 'car', 'gray', 0.620444655418396, 'a car is driving down the street in a parking lot')
# (397, '0:00:29', 'car', 'gray', 0.33709776401519775, 'a police car is seen in this und photo')
# (398, '0:00:30', 'car', 'gray', 0.7439365983009338, 'a car is seen in this image from the video')
# (399, '0:00:30', 'car', 'gray', 0.6929879188537598, 'a car is driving down the road with other cars')
# (400, '0:00:30', 'car', 'gray', 0.48554378747940063, 'the car is parked in the parking lot')
# (401, '0:00:30', 'car', 'gray', 0.44747495651245117, 'a car is seen in this und photo')
# (402, '0:00:31', 'car', 'gray', 0.6506063938140869, 'a car is parked in a parking lot')
# (403, '0:00:31', 'car', 'gray', 0.6293155550956726, 'a car driving down a street with a sign on it')
# (404, '0:00:31', 'car', 'gray', 0.5491231679916382, 'a car is seen in this image from the back')
# (405, '0:00:31', 'car', 'gray', 0.48001161217689514, 'a police car is seen in this und photo')
# (407, '0:00:31', 'car', 'gray', 0.3831355571746826, 'a blurry image of a cloud')
# (409, '0:00:31', 'car', 'gray', 0.36314383149147034, 'a police car driving down the road')
# (410, '0:00:32', 'car', 'gray', 0.7608782649040222, 'a car driving down a street with a red car')
# (411, '0:00:32', 'car', 'gray', 0.677401602268219, 'a white car is driving down the street')
# (412, '0:00:32', 'car', 'gray', 0.6582733988761902, 'a police car is seen on the side of a road')
# (413, '0:00:32', 'car', 'gray', 0.5776978135108948, 'a car is seen in this image')
# (414, '0:00:32', 'car', 'gray', 0.4246801733970642, 'a car is parked in a parking lot')
# (415, '0:00:32', 'car', 'gray', 0.37870460748672485, 'a blurry image of a cloud')
# (416, '0:00:33', 'car', 'gray', 0.7832725048065186, 'a red car driving down a street')
# (417, '0:00:33', 'car', 'gray', 0.7078946232795715, 'a car is seen in this image')
# (418, '0:00:33', 'car', 'gray', 0.5697166919708252, 'a car is shown in this image')
# (419, '0:00:33', 'car', 'gray', 0.5262084007263184, 'a police car is seen in this image')
# (420, '0:00:33', 'car', 'gray', 0.43194958567619324, 'a police car is seen on the side of a road')
# (421, '0:00:33', 'car', 'gray', 0.3877556622028351, 'a blurry image of a city')
# (422, '0:00:34', 'car', 'gray', 0.8426043391227722, 'a car is seen in this image from the video')
# (423, '0:00:34', 'car', 'gray', 0.5793893933296204, 'a car is seen in this image')
# (424, '0:00:34', 'car', 'gray', 0.47723013162612915, 'a white car is parked in a parking lot')
# (425, '0:00:34', 'car', 'gray', 0.33353742957115173, 'a blurry image of a car')
# (426, '0:00:34', 'car', 'gray', 0.3086562156677246, 'a police car is seen in this und photo')
# (427, '0:00:35', 'car', 'gray', 0.8017184734344482, 'a car is seen in this image')
# (428, '0:00:35', 'car', 'gray', 0.5197852849960327, 'a car is seen in this image')
# (429, '0:00:35', 'car', 'gray', 0.3951174318790436, 'a man in a black shirt and black pants')
# (430, '0:00:36', 'car', 'gray', 0.5813838839530945, 'a car is seen in this image')
# (431, '0:00:36', 'car', 'gray', 0.49330219626426697, 'a blur of a car driving down a road')
# (432, '0:00:36', 'car', 'gray', 0.3941221535205841, 'a computer screen with a black background')
# (433, '0:00:37', 'car', 'gray', 0.4868899881839752, 'a car is seen in this image')
# (434, '0:00:37', 'car', 'gray', 0.4218451976776123, 'a car is seen in this image')
# (435, '0:00:38', 'car', 'gray', 0.3933236300945282, 'a car is seen in this image')
# (436, '0:00:38', 'car', 'gray', 0.3707118034362793, 'a white car is parked in the dark')
# (437, '0:00:39', 'car', 'gray', 0.4670282304286957, 'a black and white photo of a car')
# (438, '0:00:40', 'car', 'gray', 0.4592472314834595, 'a car is seen in this image')
# (439, '0:00:41', 'car', 'gray', 0.5847542881965637, 'a blur of a car driving down a street')
# (440, '0:00:42', 'car', 'gray', 0.6987511515617371, 'a car is shown in this image')
# (441, '0:00:43', 'car', 'gray', 0.6859782934188843, 'a car is seen in this image')
# (442, '0:00:44', 'car', 'gray', 0.6244880557060242, 'a car driving down a road with a blur')
# (443, '0:00:45', 'car', 'gray', 0.5887666344642639, 'a car driving down a road with a sign on it')
# (444, '0:00:46', 'car', 'gray', 0.5305317044258118, 'a car driving down a road with a blue sky background')
# (445, '0:00:47', 'car', 'gray', 0.8719882369041443, 'a blue truck driving down a road')
# (446, '0:00:47', 'car', 'gray', 0.4243524968624115, 'a white car is seen in this image')
# (447, '0:00:48', 'car', 'gray', 0.3006395697593689, 'a blue van driving down a street')
# (448, '0:00:51', 'car', 'gray', 0.30659112334251404, 'a car is seen in this image')
# (449, '0:00:52', 'car', 'gray', 0.6990445256233215, 'a car is seen in this image')
# (450, '0:00:53', 'car', 'gray', 0.487071692943573, 'a car is seen in this image')
# (451, '0:00:54', 'car', 'gray', 0.8020655512809753, 'a white car is shown in the dark')
# (452, '0:00:55', 'car', 'gray', 0.5774593949317932, 'a car driving down a street at night')
# (453, '0:00:56', 'car', 'gray', 0.5193118453025818, 'a car driving down a road with a blur')
# (454, '0:00:57', 'car', 'gray', 0.7914548516273499, 'a car driving down a road with a light on it')
# (455, '0:00:57', 'car', 'gray', 0.333867609500885, 'a white truck parked in a parking lot')
# (456, '0:00:58', 'car', 'gray', 0.8488995432853699, 'a car driving down a road with a white car')
# (457, '0:00:59', 'car', 'gray', 0.3126083314418793, 'a white car is seen in this image')
# (458, '0:01:00', 'car', 'gray', 0.3306126892566681, 'the car is seen in this image')
# (459, '0:01:00', 'car', 'gray', 0.3139011859893799, 'a white car is driving down the street')
# (460, '0:01:01', 'car', 'gray', 0.6864906549453735, 'a white car is shown in this image')
# (461, '0:01:01', 'car', 'gray', 0.5223464965820312, 'a white car driving down a street')
# (462, '0:01:02', 'car', 'gray', 0.739564061164856, 'a car is seen in this image')
# (463, '0:01:02', 'car', 'gray', 0.4739816188812256, 'a white car driving down a road')
# (464, '0:01:03', 'car', 'gray', 0.8258854746818542, 'a car is seen in this image')
# (465, '0:01:03', 'car', 'gray', 0.5550389289855957, 'a white car driving down a road')
# (466, '0:01:04', 'car', 'gray', 0.7955560684204102, 'a car driving down a road with a blur')
# (467, '0:01:04', 'car', 'gray', 0.4460948407649994, 'a white van is driving down the road')
# (468, '0:01:05', 'car', 'gray', 0.8242030143737793, 'a silver car driving down a road')
# (469, '0:01:05', 'car', 'gray', 0.4056893289089203, 'a white car driving down a street')
# (470, '0:01:06', 'car', 'gray', 0.7190529108047485, 'a car is seen in this image')
# (471, '0:01:06', 'car', 'gray', 0.5686745643615723, 'a white car with a black background')
# (472, '0:01:06', 'car', 'gray', 0.487148642539978, 'a white car driving down a street')
# (473, '0:01:07', 'car', 'gray', 0.6709322929382324, 'a car driving down a street at night')
# (474, '0:01:07', 'car', 'gray', 0.6579771637916565, 'a white van driving down a road')
# (475, '0:01:07', 'car', 'gray', 0.5202076435089111, 'a white car driving down a road')
# (476, '0:01:08', 'car', 'gray', 0.6489320993423462, 'a white van driving down a road')
# (477, '0:01:08', 'car', 'gray', 0.5567857623100281, 'a white car driving down a race track')
# (478, '0:01:08', 'car', 'gray', 0.3823032081127167, 'a car driving down a street at night')
# (479, '0:01:09', 'car', 'gray', 0.617759108543396, 'a white van driving down a road')
# (480, '0:01:09', 'car', 'gray', 0.5732787251472473, 'a car driving down a street at night')
# (481, '0:01:09', 'car', 'gray', 0.5655199885368347, 'a white truck driving down a road')
# (482, '0:01:10', 'car', 'gray', 0.6717982292175293, 'a car driving down a road with a light on it')
# (483, '0:01:10', 'car', 'gray', 0.5244522094726562, 'a white car driving down a road')
# (484, '0:01:10', 'car', 'gray', 0.43244701623916626, 'a car is seen in this image')
# (485, '0:01:11', 'car', 'gray', 0.6794835329055786, 'a car driving down a road with a blur')
# (486, '0:01:11', 'car', 'gray', 0.6601799130439758, 'a truck driving down a highway with a sign on it')
# (487, '0:01:11', 'car', 'gray', 0.6054019331932068, 'a white truck driving down a road')
# (488, '0:01:11', 'car', 'gray', 0.35177236795425415, 'a blurry image of a car')
# (489, '0:01:12', 'car', 'gray', 0.689186692237854, 'the car is driving down the road')
# (490, '0:01:12', 'car', 'gray', 0.44958987832069397, 'a white car driving down a road')
# (491, '0:01:12', 'car', 'black', 0.4422805607318878, 'a truck driving down a highway with a sign')
# (492, '0:01:12', 'car', 'gray', 0.4192274212837219, 'a police car is parked in the parking')
# (493, '0:01:12', 'car', 'gray', 0.41153380274772644, 'a blur effect effect effect effect effect effect effect effect effect effect effect effect effect effect effect effect effect effect effect')
# (494, '0:01:13', 'car', 'black', 0.6650204658508301, 'a blue van driving down a street')
# (495, '0:01:13', 'car', 'gray', 0.5160906314849854, 'two cars driving down a road with a truck behind them')
# (496, '0:01:13', 'car', 'gray', 0.48434916138648987, 'a car is shown in this image')
# (497, '0:01:13', 'car', 'gray', 0.4490099251270294, 'a white car driving down a street')
# (498, '0:01:14', 'car', 'gray', 0.6482304930686951, "ford ' s new eco - drive concept is a big deal")
# (499, '0:01:14', 'car', 'gray', 0.44100117683410645, 'a car is shown in this image')
# (500, '0:01:14', 'car', 'gray', 0.4016590714454651, 'the car is parked in the parking lot')
# (501, '0:01:14', 'car', 'gray', 0.37518826127052307, 'a white car driving down a street')
# (502, '0:01:15', 'car', 'gray', 0.5209581255912781, 'a white van driving down a street')
# (503, '0:01:15', 'car', 'gray', 0.4692906439304352, 'the bmw x1 is seen in this image')
# (504, '0:01:16', 'car', 'gray', 0.8009986877441406, 'the car is driving down the road')
# (505, '0:01:16', 'car', 'gray', 0.4128139317035675, 'a white car driving down a street')
# (506, '0:01:17', 'car', 'gray', 0.6138134002685547, 'the front end of a car with a white light on it')
# (507, '0:01:17', 'car', 'gray', 0.3203340768814087, 'a white car driving down a road')
# (508, '0:01:18', 'car', 'gray', 0.795462429523468, 'the front of a blue car driving down a road')
# (509, '0:01:18', 'car', 'gray', 0.3938373029232025, 'the new ford edge sport is a good looking car')
# (510, '0:01:19', 'car', 'black', 0.7474921941757202, 'the chevrolet cruz is seen in this und photo')
# (511, '0:01:19', 'car', 'gray', 0.6470067501068115, 'a white car driving down a street')
# (512, '0:01:20', 'car', 'gray', 0.383280873298645, 'a white car driving down a street')
# (513, '0:01:21', 'car', 'gray', 0.7280154824256897, 'a police car is parked on the side of the road')
# (514, '0:01:21', 'car', 'gray', 0.4324589967727661, 'the new bmw x1')
# (515, '0:01:22', 'car', 'gray', 0.7672587037086487, 'a white car is seen in this image')
# (516, '0:01:22', 'car', 'gray', 0.5073128342628479, 'a police car is driving down the street')
# (518, '0:01:22', 'car', 'gray', 0.3682986795902252, 'a black and white photo of clouds')
#
# All silver vehicles detected:
# (6, '0', 'car', 'silver', 0.31140992045402527, 'a white van parked in a parking lot')
# (267, '0:00:00', 'car', 'silver', 0.31140992045402527, 'a white van parked in a parking lot')
#
# All alerts generated:
# (1, '0:00:00', 'ALERT: Silver car detected at 0:00:00 (lat=37.77490, lon=-122.41940, alt=100.00)')
#
# All telemetry records (first 5 shown):
# (1, '0', 37.7749, -122.4194, 100.0)
# (2, '0', 37.7749, -122.4194, 100.0)
# (3, '0', 37.7749, -122.4194, 100.0)
# (4, '0', 37.7749, -122.4194, 100.0)
# (5, '0', 37.7749, -122.4194, 100.0)
# Test Passed: 518 detections found in DB.

# %%
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyBDS-dAWUkBr8Figh-Jro_sgY6q8nKSb60"  # Replace with your actual API key


from langchain_google_genai import ChatGoogleGenerativeAI

# Gemini 1.5 Pro model setup
llm = ChatGoogleGenerativeAI(model="gemini-1.5-pro", temperature=0.4)

def summarize_video_with_gemini(frame_descriptions: list):
    joined_frames = "\n".join(frame_descriptions)
    prompt = (
        f"Here is a video described frame by frame:\n{joined_frames}\n\n"
        "Generate a 1-sentence summary of the video."
    )
    
    response = llm.invoke(prompt)
    return response.content.strip()

def ask_question_on_video(frames: list, user_question: str):
    context = "\n".join(frames)
    prompt = (
        f"Here is the frame-by-frame description of a video:\n{context}\n\n"
        f"Now answer the following question based on the video: {user_question}"
    )

    response = llm.invoke(prompt)
    return response.content.strip()

import sqlite3

# Connect to the DB
conn = sqlite3.connect("drone_security.db")
cursor = conn.cursor()

# Fetch the frame-wise object descriptions
cursor.execute("SELECT blip_caption FROM detections ORDER BY detection_id ASC")
rows = cursor.fetchall()

# Extract descriptions from query results
frames = [row[0] for row in rows if row[0]]  # ignore NULLs if any

conn.close()

video_summary = summarize_video_with_gemini(frames)
print("📽️ Video Summary:", video_summary)

# Follow-up Q&A
q1 = ask_question_on_video(frames, "What objects were seen in the video?")
q2 = ask_question_on_video(frames, "Was there any suspicious activity?")

print("🤖 Q1 Response:", q1)
print("🤖 Q2 Response:", q2)
# Out:
# 📽️ Video Summary: This video shows a variety of vehicles, including cars, trucks, vans, buses, and police cars, driving and parked in various locations and conditions.
# 🤖 Q1 Response: The video primarily features various vehicles in motion or parked.  The most common objects are:
#
# * **Cars:**  Many different cars, described by color (white, red, blue), type (van, truck, police car, school bus), and sometimes make and model (BMW X1, BMW X6, Chevrolet Camaro, Chevrolet Cruz, Ford Edge).
# * **Trucks:** Including semi-trucks with trailers and trucks with different colored cabs.
# * **Vans:**  Often white vans, sometimes with additional color details.
# * **Buses:** Including school buses.
# * **Police Cars:** Both in motion and parked.
#
# Additionally, there are a few less common objects/scenes:
#
# * **Road signs:**  Seen alongside the roads the vehicles are driving on.
# * **Traffic lights:** At least one red light is mentioned.
# * **Buildings:**  Some vehicles are seen driving next to buildings.
# * **Parking lots:**  Cars and trucks are seen parked in parking lots.
# * **People:**  Occasionally mentioned inside the vehicles.
# * **Fog:**  Present in some scenes.
# * **Smoke:**  Seen in the background of one scene.
# * **A blurry cloud:**  Mentioned a few times, likely due to poor video quality or camera movement.
# * **A man in a suit:**  Seen in a black and white photo, the context of which is unclear.
# * **A large white box with a black lid:** The context is unclear.
# * **A computer screen with a black background:** The context is unclear.
#
#
# The descriptions are often repetitive and sometimes vague ("a car is seen in this image"), indicating the video might be long and potentially monotonous.
# 🤖 Q2 Response: While the descriptions mention police cars multiple times, there's no explicit mention of an arrest, chase, or any other activity that would definitively indicate suspicious activity.  The presence of police cars alone doesn't necessarily mean anything illegal occurred. They could be patrolling, responding to an unrelated call, or even just parked.  Therefore, based on these descriptions, we **cannot conclude** that any suspicious activity took place.
